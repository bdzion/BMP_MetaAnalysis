# %%
import matplotlib.pyplot as plt

# Data from the simplified version for box plots
# Tile flow as percentage of annual precipitation
field_scale_precipitation = [16, 41, 26, 66, 11, 40, 17, 22, 13.7, 21.9, 17.5, 32]
watershed_scale_precipitation = [8.5, 16.2, 13, 19, 34.14]

# Tile flow as percentage of total flow
field_scale_total_flow = [78, 90, 80, 97, 81, 96, 83, 90]
watershed_scale_total_flow = [42, 53, 80, 40, 45, 47]

# Combine the data for the single plot
data = [
    field_scale_precipitation, 
    watershed_scale_precipitation, 
    field_scale_total_flow, 
    watershed_scale_total_flow
]

# Labels for the boxplot groups
labels = [
    "Field scale: % of Precipitation", 
    "Watershed scale: % of Precipitation", 
    "Field scale: % of Total Flow", 
    "Watershed scale: % of Total Flow"
]

# Colors: One shade of blue for Precipitation, another for Total Flow
colors = ['#87ceeb', '#87ceeb', '#4682b4', '#4682b4']  # Sky blue for precipitation, steel blue for flow

# Create the boxplot
fig, ax = plt.subplots(figsize=(12, 6))
box = ax.boxplot(data, patch_artist=True, labels=labels)

# Apply colors to the boxes
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Add title and axis labels
plt.title("Tile Flow as Percentage of Annual Precipitation and Total Flow", fontsize=14)
plt.ylabel("Percentage (%)", fontsize=12)
plt.xticks(fontsize=10)  # Ensure no rotation for x-axis tick labels
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Add a legend for color distinction
plt.legend([box['boxes'][0], box['boxes'][2]], 
           ['Precipitation', 'Total Flow'], 
           loc='upper right', fontsize=10, frameon=False)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the simplified version for box plots
# Tile flow as percentage of annual precipitation
field_scale_precipitation = [16, 41, 26, 66, 11, 40, 17, 22, 13.7, 21.9, 17.5, 32]
watershed_scale_precipitation = [8.5, 16.2, 13, 19, 34.14, 45]

# Tile flow as percentage of total flow
field_scale_total_flow = [78, 90, 80, 97, 81, 96, 83, 90]
watershed_scale_total_flow = [42, 53, 80, 40, 45, 47]

# Combine the data for the single plot
data = [
    field_scale_precipitation, 
    watershed_scale_precipitation, 
    field_scale_total_flow, 
    watershed_scale_total_flow
]

# Number of values for each dataset
n_values = [
    len(field_scale_precipitation), 
    len(watershed_scale_precipitation), 
    len(field_scale_total_flow), 
    len(watershed_scale_total_flow)
]

# Labels for the boxplot groups (including n= values)
labels = [
    f"Field scale:\n % of Precipitation\n(n={n_values[0]})",
    f"Watershed scale:\n % of Precipitation\n(n={n_values[1]})",
    f"Field scale:\n % of Total Flow\n(n={n_values[2]})",
    f"Watershed scale:\n % of Total Flow\n(n={n_values[3]})"
]

# Colors: One shade of blue for Precipitation, another for Total Flow
colors = ['#87ceeb', '#87ceeb', '#4682b4', '#4682b4']  # Sky blue for precipitation, steel blue for flow

# Create the boxplot
fig, ax = plt.subplots(figsize=(12, 6))
box = ax.boxplot(data, patch_artist=True, labels=labels)

# Apply colors to the boxes
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Add title and axis labels
plt.title("Tile Flow as a Percentage of Annual Precipitation and Total Flow", fontsize=14)
plt.ylabel("Percentage (%)", fontsize=12)
plt.xticks(fontsize=12)  # Ensure no rotation for x-axis tick labels
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Add a legend for color distinction
plt.legend([box['boxes'][0], box['boxes'][2]], 
           ['Precipitation', 'Total Flow'], 
           loc='upper right', fontsize=10, frameon=False)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# New data for box plots
data = {
    "Field-scale TP Loading in Surface Runoff": [0.4, 1.9, 0.05, 0.56, 0.01, 0.13, 0.08, 0.25, 0.51, 1.38, 0.45, 0.89, 0.37, 0.92, 0.02, 0.34, 0.6, 4.55, 3.32, 8.91],
    "Field-scale TP Loading in Tile Flow": [0.3, 2.3, 0.14, 1.62, 0.21, 2.14, 0.17, 0.26, 0.6, 0.93, 0.64, 1.47, 0.66, 1.34, 0.58, 1.47, 0.15, 0.72, 0.01, 0.46, 0.73, 8.36, 2.02, 3.21, 1.04, 3.45, 0.58, 0.6, 0.18, 0.9, 0.24, 1.53, 0.49, 6.93, 0.27, 2.63, 0.01, 0.08, 0.01, 0.19, 0.44, 0.75, 2.85],
    "Field-scale DRP Loading in Surface Runoff": [0.17, 0.43, 0.003, 0.08, 0.001, 0.013, 0.01, 0.08, 0.26, 0.34, 0.11, 0.21, 0.18, 0.24, 0.15, 0.38, 0.009, 0.12, 0.22, 0.95, 0.52, 7.84, 3.32, 7.84, 0.39, 0.35],
    "Field-scale DRP Loading in Tile Flow": [0.21, 0.53, 0.008, 0.152, 0.01, 0.12, 0.017, 0.023, 0.06, 0.28, 0.14, 0.32, 0.19, 0.55, 0.24, 0.51, 0.02, 0.2, 0.01, 0.03, 0.003, 0.104, 0.19, 6.28, 0.18, 0.9, 0.27, 2.43, 0.28, 0.34, 0.06, 0.69, 0.22, 0.95, 0.36, 5.86, 0.13, 2.08, 0.01, 0.06, 0.01, 0.15, 0.36, 0.61, 0.89, 0.79, 0.68, 0.344, 0.383],
    "Field-scale PP Loading in Surface Runoff": [0.08, 0.73, 0.04, 0.51, 0.008, 0.102, 0.07, 0.2, 0.46, 0.99, 0.14, 0.29, 0.23, 0.58, 0.17, 0.47, 1.29, 1.14],
    "Field-scale PP Loading in Tile Flow": [0.09, 1.77, 0.1, 1.33, 0.19, 1.82, 0.15, 0.23, 0.33, 0.64, 0.23, 1.15, 0.24, 1.27, 0.17, 0.98, 0.46, 1.46, 2.11, 3.14],
    "Watershed-scale TP Loading in Surface Runoff": [0.94, 0.52, 1.85, 0.18, 1.8, 0.77, 1.11, 0.99, 1.85, 1.1, 3.3],
    "Watershed-scale TP Loading in Tile Flow": [0.28, 0.92, 0.003, 0.322, 0.18],
    "Watershed-scale DRP Loading in Surface Runoff": [0.1, 0.15, 0.33, 1.26, 0.471, 0.05, 0.13, 0.34, 0.051, 0.34, 0.82, 0.63],
    "Watershed-scale DRP Loading in Tile Flow": [0.22, 0.84, 0.11, 0.23, 0.002, 0.248, 0.1, 0.017, 0.023],
}

# Assign two colors: blue for Field-scale, green for Watershed-scale
colors = ['skyblue' if 'Field' in key else 'lightgreen' for key in data.keys()]

# Get the number of data points (n values)
n_values = [len(values) for values in data.values()]
labels_with_n = [f"{key}\n(n={n})" for key, n in zip(data.keys(), n_values)]

# Create horizontal box plots
fig, ax = plt.subplots(figsize=(12, 10))
box = ax.boxplot(data.values(), patch_artist=True, vert=False, labels=labels_with_n)

# Apply colors to the boxes
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Customize the plot
ax.set_title("(a) Phosphorus Loadings (kg/ha) from Tile-Drained Fields and Watersheds", fontsize=14, fontweight="bold")
ax.set_xlabel("Loading Values (kg/ha)", fontsize=14)
ax.grid(axis="x", linestyle="--", alpha=0.7)
ax.tick_params(axis='y', labelsize=12)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale TP Loading in Surface Runoff": [0.4, 1.9, 0.05, 0.56, 0.01, 0.13, 0.08, 0.25, 0.51, 1.38, 0.45, 0.89, 0.37, 0.92, 0.02, 0.34, 0.6, 4.55, 3.32, 8.91],
    "Field-scale TP Loading in Tile Flow": [0.3, 2.3, 0.14, 1.62, 0.21, 2.14, 0.17, 0.26, 0.6, 0.93, 0.64, 1.47, 0.66, 1.34, 0.58, 1.47, 0.15, 0.72, 0.01, 0.46, 0.73, 8.36, 2.02, 3.21, 1.04, 3.45, 0.58, 0.6, 0.18, 0.9, 0.24, 1.53, 0.49, 6.93, 0.27, 2.63, 0.01, 0.08, 0.01, 0.19, 0.44, 0.75, 2.85],
    "Field-scale DRP Loading in Surface Runoff": [0.17, 0.43, 0.003, 0.08, 0.001, 0.013, 0.01, 0.08, 0.26, 0.34, 0.11, 0.21, 0.18, 0.24, 0.15, 0.38, 0.009, 0.12, 0.22, 0.95, 0.52, 7.84, 3.32, 7.84, 0.39, 0.35],
    "Field-scale DRP Loading in Tile Flow": [0.21, 0.53, 0.008, 0.152, 0.01, 0.12, 0.017, 0.023, 0.06, 0.28, 0.14, 0.32, 0.19, 0.55, 0.24, 0.51, 0.02, 0.2, 0.01, 0.03, 0.003, 0.104, 0.19, 6.28, 0.18, 0.9, 0.27, 2.43, 0.28, 0.34, 0.06, 0.69, 0.22, 0.95, 0.36, 5.86, 0.13, 2.08, 0.01, 0.06, 0.01, 0.15, 0.36, 0.61, 0.89, 0.79, 0.68, 0.344, 0.383],
    "Field-scale PP Loading in Surface Runoff": [0.08, 0.73, 0.04, 0.51, 0.008, 0.102, 0.07, 0.2, 0.46, 0.99, 0.14, 0.29, 0.23, 0.58, 0.17, 0.47, 1.29, 1.14],
    "Field-scale PP Loading in Tile Flow": [0.09, 1.77, 0.1, 1.33, 0.19, 1.82, 0.15, 0.23, 0.33, 0.64, 0.23, 1.15, 0.24, 1.27, 0.17, 0.98, 0.46, 1.46, 2.11, 3.14],
    "Watershed-scale TP Loading in Surface Runoff": [0.94, 0.52, 1.85, 0.18, 1.8, 0.77, 1.11, 0.99, 1.85, 1.1, 3.3],
    "Watershed-scale TP Loading in Tile Flow": [0.28, 0.92, 0.003, 0.322, 0.18],
    "Watershed-scale DRP Loading in Surface Runoff": [0.1, 0.15, 0.33, 1.26, 0.471, 0.05, 0.13, 0.34, 0.051, 0.34, 0.82, 0.63],
    "Watershed-scale DRP Loading in Tile Flow": [0.22, 0.84, 0.11, 0.23, 0.002, 0.248, 0.1, 0.017, 0.023],
}

# Perform Monte Carlo Simulation for each dataset
results = {}
for key, values in data.items():
    # Fit a log-normal distribution (appropriate for environmental data)
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    
    # Generate 10,000 random samples
    simulated_samples = stats.lognorm.rvs(shape, loc, scale, size=10000)
    
    # Calculate 95% confidence intervals
    ci_lower = np.percentile(simulated_samples, 2.5)
    ci_upper = np.percentile(simulated_samples, 97.5)
    
    # Store results
    results[key] = {
        "mean": np.mean(simulated_samples),
        "median": np.median(simulated_samples),
        "ci_lower": ci_lower,
        "ci_upper": ci_upper,
    }

# Print results
for key, result in results.items():
    print(f"{key}:")
    print(f"  Mean: {result['mean']:.2f}")
    print(f"  Median: {result['median']:.2f}")
    print(f"  95% CI: [{result['ci_lower']:.2f}, {result['ci_upper']:.2f}]")
# Out:
# Field-scale TP Loading in Surface Runoff:
#   Mean: 1.70
#   Median: 0.40
#   95% CI: [0.02, 11.31]
# Field-scale TP Loading in Tile Flow:
#   Mean: 1.78
#   Median: 0.56
#   95% CI: [0.03, 11.23]
# Field-scale DRP Loading in Surface Runoff:
#   Mean: 1.50
#   Median: 0.16
#   95% CI: [0.00, 9.94]
# Field-scale DRP Loading in Tile Flow:
#   Mean: 0.71
#   Median: 0.18
#   95% CI: [0.01, 4.81]
# Field-scale PP Loading in Surface Runoff:
#   Mean: 0.53
#   Median: 0.23
#   95% CI: [0.02, 2.80]
# Field-scale PP Loading in Tile Flow:
#   Mean: 0.96
#   Median: 0.52
#   95% CI: [0.06, 4.46]
# Watershed-scale TP Loading in Surface Runoff:
#   Mean: 1.38
#   Median: 1.06
#   95% CI: [0.24, 4.47]
# Watershed-scale TP Loading in Tile Flow:
#   Mean: 0.88
#   Median: 0.13
#   95% CI: [0.00, 6.09]
# Watershed-scale DRP Loading in Surface Runoff:
#   Mean: 0.42
#   Median: 0.25
#   95% CI: [0.03, 1.86]
# Watershed-scale DRP Loading in Tile Flow:
#   Mean: 0.33
#   Median: 0.08
#   95% CI: [0.00, 2.20]

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale TP Loading in Surface Runoff": [0.4, 1.9, 0.05, 0.56, 0.01, 0.13, 0.08, 0.25, 0.51, 1.38, 0.45, 0.89, 0.37, 0.92, 0.02, 0.34, 0.6, 4.55, 3.32, 8.91],
    "Field-scale TP Loading in Tile Flow": [0.3, 2.3, 0.14, 1.62, 0.21, 2.14, 0.17, 0.26, 0.6, 0.93, 0.64, 1.47, 0.66, 1.34, 0.58, 1.47, 0.15, 0.72, 0.01, 0.46, 0.73, 8.36, 2.02, 3.21, 1.04, 3.45, 0.58, 0.6, 0.18, 0.9, 0.24, 1.53, 0.49, 6.93, 0.27, 2.63, 0.01, 0.08, 0.01, 0.19, 0.44, 0.75, 2.85],
    "Field-scale DRP Loading in Surface Runoff": [0.17, 0.43, 0.003, 0.08, 0.001, 0.013, 0.01, 0.08, 0.26, 0.34, 0.11, 0.21, 0.18, 0.24, 0.15, 0.38, 0.009, 0.12, 0.22, 0.95, 0.52, 7.84, 3.32, 7.84, 0.39, 0.35],
    "Field-scale DRP Loading in Tile Flow": [0.21, 0.53, 0.008, 0.152, 0.01, 0.12, 0.017, 0.023, 0.06, 0.28, 0.14, 0.32, 0.19, 0.55, 0.24, 0.51, 0.02, 0.2, 0.01, 0.03, 0.003, 0.104, 0.19, 6.28, 0.18, 0.9, 0.27, 2.43, 0.28, 0.34, 0.06, 0.69, 0.22, 0.95, 0.36, 5.86, 0.13, 2.08, 0.01, 0.06, 0.01, 0.15, 0.36, 0.61, 0.89, 0.79, 0.68, 0.344, 0.383],
    "Field-scale PP Loading in Surface Runoff": [0.08, 0.73, 0.04, 0.51, 0.008, 0.102, 0.07, 0.2, 0.46, 0.99, 0.14, 0.29, 0.23, 0.58, 0.17, 0.47, 1.29, 1.14],
    "Field-scale PP Loading in Tile Flow": [0.09, 1.77, 0.1, 1.33, 0.19, 1.82, 0.15, 0.23, 0.33, 0.64, 0.23, 1.15, 0.24, 1.27, 0.17, 0.98, 0.46, 1.46, 2.11, 3.14],
    "Watershed-scale TP Loading in Surface Runoff": [0.94, 0.52, 1.85, 0.18, 1.8, 0.77, 1.11, 0.99, 1.85, 1.1, 3.3],
    "Watershed-scale TP Loading in Tile Flow": [0.28, 0.92, 0.003, 0.322, 0.18],
    "Watershed-scale DRP Loading in Surface Runoff": [0.1, 0.15, 0.33, 1.26, 0.471, 0.05, 0.13, 0.34, 0.051, 0.34, 0.82, 0.63],
    "Watershed-scale DRP Loading in Tile Flow": [0.22, 0.84, 0.11, 0.23, 0.002, 0.248, 0.1, 0.017, 0.023],
}

# Perform Monte Carlo Simulation and store statistics
results = {}
all_means, all_medians, all_ci_lowers, all_ci_uppers, categories = [], [], [], [], []
for key, values in data.items():
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    simulated_samples = stats.lognorm.rvs(shape, loc, scale, size=10000)
    
    mean = np.mean(simulated_samples)
    median = np.median(simulated_samples)
    ci_lower = np.percentile(simulated_samples, 2.5)
    ci_upper = np.percentile(simulated_samples, 97.5)
    
    all_means.append(mean)
    all_medians.append(median)
    all_ci_lowers.append(ci_lower)
    all_ci_uppers.append(ci_upper)
    categories.append(key)

# Plot the results
fig, ax = plt.subplots(figsize=(12, 8))

for i, (mean, ci_lower, ci_upper) in enumerate(zip(all_means, all_ci_lowers, all_ci_uppers)):
    ax.errorbar(x=mean, y=i, xerr=[[mean - ci_lower], [ci_upper - mean]], fmt='o', color='blue', label='Mean ± 95% CI' if i == 0 else "", capsize=5)

ax.scatter(all_medians, range(len(categories)), color='red', label='Median', zorder=3)

ax.set_yticks(range(len(categories)))
ax.set_yticklabels(categories, fontsize=10)
ax.set_xlabel("Loading Values (kg/ha)", fontsize=12)
ax.set_title("Monte Carlo Simulation Results: Means and 95% CIs", fontsize=14, fontweight='bold')
ax.axvline(x=0, color='gray', linestyle='--', linewidth=0.8, zorder=0)

ax.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# New data for box plots
data = {
    "Field-scale NO3-N Loading in Tile Flow": [3.1, 3.8, 1, 18.4, 3.6, 15.4, 24.63, 43.76, 0.67, 5.88, 2.88, 8.34, 5.71, 42.95, 23.9, 56.8, 2.9, 153, 17, 37],
    "Field-scale TN Loading in Tile Flow": [34.73, 52.86, 2.09, 20.63, 28.3, 64.2, 6.6, 97.7],
    "Watershed-scale NO3-N Loading in Surface Runoff": [9.15, 11.55, 15.54, 5.27, 4.67, 2.4, 2.6, 1.5],
    "Watershed-scale NO3-N Loading in Tile Flow": [22.8, 27.36, 6.5],
    "Watershed-scale TN Loading in Surface Runoff": [0.93, 6.4, 6, 9.9, 16.35, 15.11],
}

# Assign two colors: blue for Field-scale, green for Watershed-scale
colors = ['skyblue' if 'Field-scale' in key else 'lightgreen' for key in data.keys()]

# Get the number of data points (n values)
n_values = [len(values) for values in data.values()]
labels_with_n = [f"{key}\n(n={n})" for key, n in zip(data.keys(), n_values)]

# Create horizontal box plots
fig, ax = plt.subplots(figsize=(12, 8))
box = ax.boxplot(data.values(), patch_artist=True, vert=False, labels=labels_with_n)

# Apply colors to the boxes
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Customize the plot
ax.set_title("(b) Nitrogen Loadings (kg/ha) from Tile-Drained Fields and Watersheds", fontsize=14, fontweight="bold")
ax.set_xlabel("Loading Values (kg/ha)", fontsize=14)
ax.grid(axis="x", linestyle="--", alpha=0.7)
ax.tick_params(axis='y', labelsize=12)

# Add a legend outside the plot
ax.legend([box['boxes'][0], box['boxes'][-1]], ['Field-scale', 'Watershed-scale'], 
          loc='upper center', bbox_to_anchor=(0.5, -0.1), fontsize=12, frameon=False, ncol=2)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale NO3-N Loading in Tile Flow": [3.1, 3.8, 1, 18.4, 3.6, 15.4, 24.63, 43.76, 0.67, 5.88, 2.88, 8.34, 5.71, 42.95, 23.9, 56.8, 2.9, 153, 17, 37],
    "Field-scale TN Loading in Tile Flow": [34.73, 52.86, 2.09, 20.63, 28.3, 64.2, 6.6, 97.7],
    "Watershed-scale NO3-N Loading in Surface Runoff": [9.15, 11.55, 15.54, 5.27, 4.67, 2.4, 2.6, 1.5],
    "Watershed-scale NO3-N Loading in Tile Flow": [22.8, 27.36, 6.5],
    "Watershed-scale TN Loading in Surface Runoff": [0.93, 6.4, 6, 9.9, 16.35, 15.11],
}

# Perform Monte Carlo Simulation for each dataset
results = {}
for key, values in data.items():
    # Fit a log-normal distribution (appropriate for environmental data)
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    
    # Generate 10,000 random samples
    simulated_samples = stats.lognorm.rvs(shape, loc, scale, size=10000)
    
    # Calculate 95% confidence intervals
    ci_lower = np.percentile(simulated_samples, 2.5)
    ci_upper = np.percentile(simulated_samples, 97.5)
    
    # Store results
    results[key] = {
        "mean": np.mean(simulated_samples),
        "median": np.median(simulated_samples),
        "ci_lower": ci_lower,
        "ci_upper": ci_upper,
    }

# Print results
for key, result in results.items():
    print(f"{key}:")
    print(f"  Mean: {result['mean']:.2f}")
    print(f"  Median: {result['median']:.2f}")
    print(f"  95% CI: [{result['ci_lower']:.2f}, {result['ci_upper']:.2f}]")
# Out:
# Field-scale NO3-N Loading in Tile Flow:
#   Mean: 26.54
#   Median: 10.09
#   95% CI: [0.72, 158.13]
# Field-scale TN Loading in Tile Flow:
#   Mean: 47.23
#   Median: 23.37
#   95% CI: [2.18, 245.11]
# Watershed-scale NO3-N Loading in Surface Runoff:
#   Mean: 6.74
#   Median: 5.00
#   95% CI: [1.10, 23.25]
# Watershed-scale NO3-N Loading in Tile Flow:
#   Mean: 19.57
#   Median: 16.01
#   95% CI: [4.49, 55.55]
# Watershed-scale TN Loading in Surface Runoff:
#   Mean: 10.54
#   Median: 6.65
#   95% CI: [0.98, 43.88]

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale NO3-N Loading in Tile Flow": [3.1, 3.8, 1, 18.4, 3.6, 15.4, 24.63, 43.76, 0.67, 5.88, 2.88, 8.34, 5.71, 42.95, 23.9, 56.8, 2.9, 153, 17, 37],
    "Field-scale TN Loading in Tile Flow": [34.73, 52.86, 2.09, 20.63, 28.3, 64.2, 6.6, 97.7],
    "Watershed-scale NO3-N Loading in Surface Runoff": [9.15, 11.55, 15.54, 5.27, 4.67, 2.4, 2.6, 1.5],
    "Watershed-scale NO3-N Loading in Tile Flow": [22.8, 27.36, 6.5],
    "Watershed-scale TN Loading in Surface Runoff": [0.93, 6.4, 6, 9.9, 16.35, 15.11],
}

# Perform Monte Carlo Simulation and store statistics
results = {}
all_means, all_medians, all_ci_lowers, all_ci_uppers, categories = [], [], [], [], []
for key, values in data.items():
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    simulated_samples = stats.lognorm.rvs(shape, loc, scale, size=10000)
    
    mean = np.mean(simulated_samples)
    median = np.median(simulated_samples)
    ci_lower = np.percentile(simulated_samples, 2.5)
    ci_upper = np.percentile(simulated_samples, 97.5)
    
    all_means.append(mean)
    all_medians.append(median)
    all_ci_lowers.append(ci_lower)
    all_ci_uppers.append(ci_upper)
    categories.append(key)

# Plot the results
fig, ax = plt.subplots(figsize=(12, 8))

for i, (mean, ci_lower, ci_upper) in enumerate(zip(all_means, all_ci_lowers, all_ci_uppers)):
    ax.errorbar(x=mean, y=i, xerr=[[mean - ci_lower], [ci_upper - mean]], fmt='o', color='blue', label='Mean ± 95% CI' if i == 0 else "", capsize=5)

ax.scatter(all_medians, range(len(categories)), color='red', label='Median', zorder=3)

ax.set_yticks(range(len(categories)))
ax.set_yticklabels(categories, fontsize=10)
ax.set_xlabel("Loading Values (kg/ha)", fontsize=12)
ax.set_title("Monte Carlo Simulation Results: Means and 95% CIs", fontsize=14, fontweight='bold')
ax.axvline(x=0, color='gray', linestyle='--', linewidth=0.8, zorder=0)

ax.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Grouped data for management strategies
data = {
    "Management at the source": {
        "Nitrogen (NO3-N and TN) loads\n reduction potential %": [3.5, 13.7, 14, 16, 67, 27, 72, 69, 90, 21, 38, 14, 16, 43.6, 48.6, 59, 62, 43],
        "Phosphorus (TP, DRP, and PP) loads\n reduction potential %": [4.3, 25.4, 18, 10, 53.98, 48.12, 7, 58, 31, 30],
    },
    "Control at the edge-of-field": {
        "Nitrogen (NO3-N) loads\n reduction potential %": [30.5, 33.61, 38, 39, 26, 43, 47, 48, 28, 52, 71, 85, 37, 46, 8, 84],
        "Phosphorus (TP and DRP) loads\n reduction potential %": [23, 55, 40, 68, 57],
    },
    "Watershed management with BMPs": {
        "Overall nutrient loads\n reduction potential %": [80, 55.8, 38.5, 22, 31, 67],
    },
}

# Plotting colors for each strategy
strategy_colors = {
    "Management at the source": "skyblue",
    "Control at the edge-of-field": "lightgreen",
    "Watershed management with BMPs": "coral",
}

# Create subplots for the strategies
fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True)  # 3 horizontal subplots

# Loop through each strategy and create individual horizontal box plots
for ax, (strategy, nutrients) in zip(axes, data.items()):
    # Extract nutrient types and values
    nutrient_names = list(nutrients.keys())
    nutrient_values = list(nutrients.values())
    
    # Create horizontal boxplot
    box = ax.boxplot(
        nutrient_values,
        patch_artist=True,
        labels=nutrient_names,
        vert=False,  # Horizontal boxplot
    )
    
    # Apply consistent color to the boxes
    for patch in box["boxes"]:
        patch.set_facecolor(strategy_colors[strategy])
    
    # Customize the subplot
    ax.set_title(strategy, fontsize=14, fontweight="bold", pad=10)
    ax.set_yticklabels(nutrient_names, fontsize=12)
    

# Adjust layout for clarity
plt.tight_layout()

# Show the plots
plt.show()

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Grouped data for management strategies
data = {
    "Management at the source": {
        "Nitrogen (NO3-N and TN) loads\n reduction potential %": [3.5, 13.7, 14, 16, 67, 27, 72, 69, 90, 21, 38, 14, 16, 43.6, 48.6, 59, 62, 43],
        "Phosphorus (TP, DRP, and PP) loads\n reduction potential %": [4.3, 25.4, 18, 10, 53.98, 48.12, 7, 58, 31, 30],
    },
    "Control at the edge-of-field": {
        "Nitrogen (NO3-N) loads\n reduction potential %": [30.5, 33.61, 38, 39, 26, 43, 47, 48, 28, 52, 71, 85, 37, 46, 8, 84],
        "Phosphorus (TP and DRP) loads\n reduction potential %": [23, 55, 40, 68, 57],
    },
    "Watershed management with a combination of BMPs": {
        "Overall nutrient loads\n reduction potential %": [80, 55.8, 38.5, 22, 31, 67],
    },
}


# Function to perform Monte Carlo simulation for a dataset
def monte_carlo_simulation(values, n_simulations=10000):
    # Fit a normal distribution (change to log-normal if needed)
    mean, std = np.mean(values), np.std(values)
    simulated_values = np.random.normal(mean, std, size=n_simulations)
    
    # Calculate confidence intervals
    ci_lower = np.percentile(simulated_values, 2.5)
    ci_upper = np.percentile(simulated_values, 97.5)
    
    return simulated_values, ci_lower, ci_upper, mean, std

# Visualization: Monte Carlo histograms and confidence intervals
fig, axes = plt.subplots(3, 1, figsize=(10, 18))  # One subplot per management strategy

for ax, (strategy, nutrients) in zip(axes, data.items()):
    ax.set_title(strategy, fontsize=14, fontweight="bold", pad=10)
    ax.set_xlabel("Reduction Potential (%)", fontsize=12)
    ax.set_ylabel("Frequency", fontsize=12)
    ax.grid(axis="y", linestyle="--", alpha=0.7)

    for nutrient, values in nutrients.items():
        # Perform Monte Carlo simulation
        simulated, ci_lower, ci_upper, mean, std = monte_carlo_simulation(values)
        
        # Plot histogram
        ax.hist(simulated, bins=30, alpha=0.6, label=f"{nutrient}\nMean: {mean:.2f}, 95% CI: [{ci_lower:.2f}, {ci_upper:.2f}]")
        
    # Add legend
    ax.legend(loc="upper right", fontsize=10)

# Adjust layout and show the plot
fig.suptitle("Monte Carlo Simulation: Nutrient Load Reduction Potential", fontsize=16, fontweight="bold")
plt.tight_layout()
plt.subplots_adjust(top=0.9)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale TP Loading in Surface Runoff": [0.4, 1.9, 0.05, 0.56, 0.01, 0.13, 0.08, 0.25, 0.51, 1.38, 0.45, 0.89, 0.37, 0.92, 0.02, 0.34, 0.6, 4.55, 3.32, 8.91],
    "Field-scale TP Loading in Tile Flow": [0.3, 2.3, 0.14, 1.62, 0.21, 2.14, 0.17, 0.26, 0.6, 0.93, 0.64, 1.47, 0.66, 1.34, 0.58, 1.47, 0.15, 0.72, 0.01, 0.46, 0.73, 8.36, 2.02, 3.21, 1.04, 3.45, 0.58, 0.6, 0.18, 0.9, 0.24, 1.53, 0.49, 6.93, 0.27, 2.63, 0.01, 0.08, 0.01, 0.19, 0.44, 0.75, 2.85],
    "Field-scale DRP Loading in Surface Runoff": [0.17, 0.43, 0.003, 0.08, 0.001, 0.013, 0.01, 0.08, 0.26, 0.34, 0.11, 0.21, 0.18, 0.24, 0.15, 0.38, 0.009, 0.12, 0.22, 0.95, 0.52, 7.84, 3.32, 7.84, 0.39, 0.35],
    "Field-scale DRP Loading in Tile Flow": [0.21, 0.53, 0.008, 0.152, 0.01, 0.12, 0.017, 0.023, 0.06, 0.28, 0.14, 0.32, 0.19, 0.55, 0.24, 0.51, 0.02, 0.2, 0.01, 0.03, 0.003, 0.104, 0.19, 6.28, 0.18, 0.9, 0.27, 2.43, 0.28, 0.34, 0.06, 0.69, 0.22, 0.95, 0.36, 5.86, 0.13, 2.08, 0.01, 0.06, 0.01, 0.15, 0.36, 0.61, 0.89, 0.79, 0.68, 0.344, 0.383],
    "Field-scale PP Loading in Surface Runoff": [0.08, 0.73, 0.04, 0.51, 0.008, 0.102, 0.07, 0.2, 0.46, 0.99, 0.14, 0.29, 0.23, 0.58, 0.17, 0.47, 1.29, 1.14],
    "Field-scale PP Loading in Tile Flow": [0.09, 1.77, 0.1, 1.33, 0.19, 1.82, 0.15, 0.23, 0.33, 0.64, 0.23, 1.15, 0.24, 1.27, 0.17, 0.98, 0.46, 1.46, 2.11, 3.14],
    "Watershed-scale TP Loading in Surface Runoff": [0.94, 0.52, 1.85, 0.18, 1.8, 0.77, 1.11, 0.99, 1.85, 1.1, 3.3],
    "Watershed-scale TP Loading in Tile Flow": [0.28, 0.92, 0.003, 0.322, 0.18],
    "Watershed-scale DRP Loading in Surface Runoff": [0.1, 0.15, 0.33, 1.26, 0.471, 0.05, 0.13, 0.34, 0.051, 0.34, 0.82, 0.63],
    "Watershed-scale DRP Loading in Tile Flow": [0.22, 0.84, 0.11, 0.23, 0.002, 0.248, 0.1, 0.017, 0.023],
}

# Function to perform Monte Carlo simulation
def monte_carlo_simulation(values, n_simulations=10000):
    # Fit a normal distribution
    mean, std = np.mean(values), np.std(values)
    simulated_values = np.random.normal(mean, std, size=n_simulations)
    
    # Calculate 95% confidence intervals
    ci_lower = np.percentile(simulated_values, 2.5)
    ci_upper = np.percentile(simulated_values, 97.5)
    
    return simulated_values, mean, std, ci_lower, ci_upper

# Plot results
fig, axes = plt.subplots(5, 2, figsize=(14, 20))  # 5 rows, 2 columns for subplots
axes = axes.flatten()

for ax, (nutrient, values) in zip(axes, data.items()):
    # Perform Monte Carlo simulation
    simulated, mean, std, ci_lower, ci_upper = monte_carlo_simulation(values)
    
    # Plot histogram
    ax.hist(simulated, bins=30, alpha=0.7, color="skyblue", edgecolor="black")
    ax.axvline(mean, color="red", linestyle="--", label=f"Mean: {mean:.2f}")
    ax.axvline(ci_lower, color="green", linestyle="--", label=f"95% CI: [{ci_lower:.2f}, {ci_upper:.2f}]")
    ax.axvline(ci_upper, color="green", linestyle="--")
    
    # Set title and labels
    ax.set_title(nutrient, fontsize=12, fontweight="bold")
    ax.set_xlabel("Loading (kg/ha)", fontsize=10)
    ax.set_ylabel("Frequency", fontsize=10)
    ax.legend(fontsize=8)

# Adjust layout
plt.tight_layout()
plt.suptitle("Monte Carlo Simulation for Uncertainty Analysis", fontsize=16, fontweight="bold", y=1.02)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale NO3-N Loading in Tile Flow": [3.1, 3.8, 1, 18.4, 3.6, 15.4, 24.63, 43.76, 0.67, 5.88, 2.88, 8.34, 5.71, 42.95, 23.9, 56.8, 2.9, 153, 17, 37],
    "Field-scale TN Loading in Tile Flow": [34.73, 52.86, 2.09, 20.63, 28.3, 64.2, 6.6, 97.7],
    "Watershed-scale NO3-N Loading in Surface Runoff": [9.15, 11.55, 15.54, 5.27, 4.67, 2.4, 2.6, 1.5],
    "Watershed-scale NO3-N Loading in Tile Flow": [22.8, 27.36, 6.5],
    "Watershed-scale TN Loading in Surface Runoff": [0.93, 6.4, 6, 9.9, 16.35, 15.11],
}

# Function to perform Monte Carlo simulation
def monte_carlo_simulation(values, n_simulations=10000):
    # Fit a normal distribution
    mean, std = np.mean(values), np.std(values)
    simulated_values = np.random.normal(mean, std, size=n_simulations)
    
    # Calculate 95% confidence intervals
    ci_lower = np.percentile(simulated_values, 2.5)
    ci_upper = np.percentile(simulated_values, 97.5)
    
    return simulated_values, mean, std, ci_lower, ci_upper

# Plot results
fig, axes = plt.subplots(3, 2, figsize=(14, 18))  # Subplots arranged in 3 rows, 2 columns
axes = axes.flatten()

for ax, (nutrient, values) in zip(axes, data.items()):
    # Perform Monte Carlo simulation
    simulated, mean, std, ci_lower, ci_upper = monte_carlo_simulation(values)
    
    # Plot histogram
    ax.hist(simulated, bins=30, alpha=0.7, color="skyblue", edgecolor="black")
    ax.axvline(mean, color="red", linestyle="--", label=f"Mean: {mean:.2f}")
    ax.axvline(ci_lower, color="green", linestyle="--", label=f"95% CI: [{ci_lower:.2f}, {ci_upper:.2f}]")
    ax.axvline(ci_upper, color="green", linestyle="--")
    
    # Set title and labels
    ax.set_title(nutrient, fontsize=12, fontweight="bold")
    ax.set_xlabel("Loading (kg/ha)", fontsize=10)
    ax.set_ylabel("Frequency", fontsize=10)
    ax.legend(fontsize=8)

# Adjust layout
plt.tight_layout()
plt.suptitle("Monte Carlo Simulation for Uncertainty Analysis", fontsize=16, fontweight="bold", y=1.02)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale NO3-N Loading in Tile Flow": [3.1, 3.8, 1, 18.4, 3.6, 15.4, 24.63, 43.76, 0.67, 5.88, 2.88, 8.34, 5.71, 42.95, 23.9, 56.8, 2.9, 153, 17, 37],
    "Field-scale TN Loading in Tile Flow": [34.73, 52.86, 2.09, 20.63, 28.3, 64.2, 6.6, 97.7],
    "Watershed-scale NO3-N Loading in Surface Runoff": [9.15, 11.55, 15.54, 5.27, 4.67, 2.4, 2.6, 1.5],
    "Watershed-scale NO3-N Loading in Tile Flow": [22.8, 27.36, 6.5],
    "Watershed-scale TN Loading in Surface Runoff": [0.93, 6.4, 6, 9.9, 16.35, 15.11],
}

# Function to perform Monte Carlo simulation
def monte_carlo_simulation(values, n_simulations=10000):
    # Fit a normal distribution
    mean, std = np.mean(values), np.std(values)
    simulated_values = np.random.normal(mean, std, size=n_simulations)
    
    # Calculate 95% confidence intervals
    ci_lower = np.percentile(simulated_values, 2.5)
    ci_upper = np.percentile(simulated_values, 97.5)
    
    return simulated_values, mean, std, ci_lower, ci_upper

# Adjust subplot layout based on dataset size
n_datasets = len(data)
n_cols = 2  # Fixed number of columns
n_rows = (n_datasets + n_cols - 1) // n_cols  # Calculate rows dynamically

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(14, 6 * n_rows))  # Adjust figure size
axes = axes.flatten()  # Flatten axes array for easy iteration

for ax, (nutrient, values) in zip(axes, data.items()):
    # Perform Monte Carlo simulation
    simulated, mean, std, ci_lower, ci_upper = monte_carlo_simulation(values)
    
    # Plot histogram
    ax.hist(simulated, bins=30, alpha=0.7, color="skyblue", edgecolor="black")
    ax.axvline(mean, color="red", linestyle="--", label=f"Mean: {mean:.2f}")
    ax.axvline(ci_lower, color="green", linestyle="--", label=f"95% CI: [{ci_lower:.2f}, {ci_upper:.2f}]")
    ax.axvline(ci_upper, color="green", linestyle="--")
    
    # Set title and labels
    ax.set_title(nutrient, fontsize=12, fontweight="bold")
    ax.set_xlabel("Loading (kg/ha)", fontsize=10)
    ax.set_ylabel("Frequency", fontsize=10)
    ax.legend(fontsize=8)

# Turn off unused axes
for ax in axes[len(data):]:
    ax.axis("off")

# Adjust layout
plt.tight_layout()
plt.suptitle("Monte Carlo Simulation for Uncertainty Analysis", fontsize=16, fontweight="bold", y=1.02)
plt.show()

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale NO3-N Loading in Tile Flow": [3.1, 3.8, 1, 18.4, 3.6, 15.4, 24.63, 43.76, 0.67, 5.88, 2.88, 8.34, 5.71, 42.95, 23.9, 56.8, 2.9, 153, 17, 37],
    "Field-scale TN Loading in Tile Flow": [34.73, 52.86, 2.09, 20.63, 28.3, 64.2, 6.6, 97.7],
    "Watershed-scale NO3-N Loading in Surface Runoff": [9.15, 11.55, 15.54, 5.27, 4.67, 2.4, 2.6, 1.5],
    "Watershed-scale NO3-N Loading in Tile Flow": [22.8, 27.36, 6.5],
    "Watershed-scale TN Loading in Surface Runoff": [0.93, 6.4, 6, 9.9, 16.35, 15.11],
}

# Function to perform Monte Carlo simulation using log-normal distribution
def monte_carlo_simulation(values, n_simulations=10000):
    # Fit a log-normal distribution
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    simulated_values = stats.lognorm.rvs(shape, loc, scale, size=n_simulations)

    # Calculate 95% confidence intervals
    ci_lower = np.percentile(simulated_values, 2.5)
    ci_upper = np.percentile(simulated_values, 97.5)

    return simulated_values, shape, loc, scale, ci_lower, ci_upper

# Adjust subplot layout based on dataset size
n_datasets = len(data)
n_cols = 2  # Fixed number of columns
n_rows = (n_datasets + n_cols - 1) // n_cols  # Calculate rows dynamically

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(14, 6 * n_rows))  # Adjust figure size
axes = axes.flatten()  # Flatten axes array for easy iteration

for ax, (nutrient, values) in zip(axes, data.items()):
    # Perform Monte Carlo simulation
    simulated, shape, loc, scale, ci_lower, ci_upper = monte_carlo_simulation(values)

    # Plot histogram
    ax.hist(simulated, bins=30, alpha=0.7, color="skyblue", edgecolor="black")
    ax.axvline(np.mean(simulated), color="red", linestyle="--", label=f"Mean: {np.mean(simulated):.2f}")
    ax.axvline(ci_lower, color="green", linestyle="--", label=f"95% CI: [{ci_lower:.2f}, {ci_upper:.2f}]")
    ax.axvline(ci_upper, color="green", linestyle="--")

    # Set title and labels
    ax.set_title(nutrient, fontsize=12, fontweight="bold")
    ax.set_xlabel("Loading (kg/ha)", fontsize=10)
    ax.set_ylabel("Frequency", fontsize=10)
    ax.legend(fontsize=8)

# Turn off unused axes
for ax in axes[len(data):]:
    ax.axis("off")

# Adjust layout
plt.tight_layout()
plt.suptitle("Monte Carlo Simulation for Uncertainty Analysis (Log-Normal)", fontsize=16, fontweight="bold", y=1.02)
plt.show()

# %%
import matplotlib.pyplot as plt

# Grouped data for management strategies
data = {
    "Management at the source": {
        "Nitrogen (NO3-N and TN) loads\n reduction potential %": [3.5, 13.7, 14, 16, 67, 27, 72, 69, 90, 21, 38, 14, 16, 43.6, 48.6, 59, 62, 43],
        "Phosphorus (TP, DRP, and PP) loads\n reduction potential %": [4.3, 25.4, 18, 10, 53.98, 48.12, 7, 58, 31, 30],
    },
    "Control at the edge-of-field": {
        "Nitrogen (NO3-N) loads\n reduction potential %": [30.5, 33.61, 38, 39, 26, 43, 47, 48, 28, 52, 71, 85, 37, 46, 8, 84],
        "Phosphorus (TP and DRP) loads\n reduction potential %": [23, 55, 40, 68, 57],
    },
    "Watershed management with a combination of BMPs": {  # Updated key
        "Overall nutrient loads\n reduction potential %": [80, 55.8, 38.5, 22, 31, 67],
    },
}

# Plotting colors for each strategy
strategy_colors = {
    "Management at the source": "skyblue",
    "Control at the edge-of-field": "lightgreen",
    "Watershed management with a combination of BMPs": "lightgoldenrodyellow",  # Updated color
}

# Create subplots for the strategies
fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True)  # 3 horizontal subplots

# Loop through each strategy and create individual horizontal box plots
for ax, (strategy, nutrients) in zip(axes, data.items()):
    # Extract nutrient types and values
    nutrient_names = list(nutrients.keys())
    nutrient_values = list(nutrients.values())
    
    # Get the number of data points (n values)
    n_values = [len(values) for values in nutrient_values]
    labels_with_n = [f"{name}\n(n={n})" for name, n in zip(nutrient_names, n_values)]
    
    # Create horizontal boxplot
    box = ax.boxplot(
        nutrient_values,
        patch_artist=True,
        labels=labels_with_n,
        vert=False,  # Horizontal boxplot
    )
    
    # Apply consistent color to the boxes
    for patch in box["boxes"]:
        patch.set_facecolor(strategy_colors[strategy])
    
    # Customize the subplot
    ax.set_title(strategy, fontsize=14, fontweight="bold", pad=10)
    ax.set_yticklabels(labels_with_n, fontsize=12)

# Adjust layout for clarity
plt.tight_layout()

# Show the plots
plt.show()

# %%
import matplotlib.pyplot as plt

# Grouped data for management strategies
data = {
    "Management at the source": {
        "Nitrogen (NO3-N and TN) loads\n reduction potential %": [3.5, 13.7, 14, 16, 67, 27, 72, 69, 90, 21, 38, 14, 16, 43.6, 48.6, 59, 62, 43],
        "Phosphorus (TP, DRP, and PP) loads\n reduction potential %": [4.3, 25.4, 18, 10, 53.98, 48.12, 7, 58, 31, 30],
    },
    "Control at the edge-of-field": {
        "Nitrogen (NO3-N) loads\n reduction potential %": [30.5, 33.61, 38, 39, 26, 43, 47, 48, 28, 52, 71, 85, 37, 46, 8, 84],
        "Phosphorus (TP and DRP) loads\n reduction potential %": [23, 55, 40, 68, 57],
    },
    "Watershed management with a combination of BMPs": {
        "Overall nutrient loads\n reduction potential %": [80, 55.8, 38.5, 22, 31, 67],
    },
}

# Colors for each nutrient
nutrient_colors = {
    "Nitrogen (NO3-N and TN) loads\n reduction potential %": "skyblue",
    "Phosphorus (TP, DRP, and PP) loads\n reduction potential %": "lightgreen",
    "Nitrogen (NO3-N) loads\n reduction potential %": "skyblue",
    "Phosphorus (TP and DRP) loads\n reduction potential %": "lightgreen",
    "Overall nutrient loads\n reduction potential %": "lightgoldenrodyellow",  # For watershed management
}

# Create subplots for the strategies
fig, axes = plt.subplots(3, 1, figsize=(12, 14), sharex=True)  # 3 horizontal subplots

# Loop through each strategy and create individual horizontal box plots
for ax, (strategy, nutrients) in zip(axes, data.items()):
    # Extract nutrient types and values
    nutrient_names = list(nutrients.keys())
    nutrient_values = list(nutrients.values())
    
    # Get the number of data points (n values)
    n_values = [len(values) for values in nutrient_values]
    labels_with_n = [f"{name}\n(n={n})" for name, n in zip(nutrient_names, n_values)]
    
    # Create horizontal boxplot
    box = ax.boxplot(
        nutrient_values,
        patch_artist=True,
        labels=labels_with_n,
        vert=False,  # Horizontal boxplot
    )
    
    # Apply colors to the boxes based on the nutrient type
    for patch, nutrient_name in zip(box["boxes"], nutrient_names):
        patch.set_facecolor(nutrient_colors[nutrient_name])
    
    # Customize the subplot
    ax.set_title(strategy, fontsize=18, fontweight="bold", pad=10)
    ax.set_yticklabels(labels_with_n, fontsize=16)

# Adjust layout for clarity
plt.tight_layout()

# Show the plots
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# New data for box plots
data = {
    "Field-scale TP Loading in Surface Runoff": [0.4, 1.9, 0.05, 0.56, 0.01, 0.13, 0.08, 0.25, 0.51, 1.38, 0.45, 0.89, 0.37, 0.92, 0.02, 0.34, 0.6, 4.55, 3.32, 8.91],
    "Field-scale TP Loading in Tile Flow": [0.3, 2.3, 0.14, 1.62, 0.21, 2.14, 0.17, 0.26, 0.6, 0.93, 0.64, 1.47, 0.66, 1.34, 0.58, 1.47, 0.15, 0.72, 0.01, 0.46, 0.73, 8.36, 2.02, 3.21, 1.04, 3.45, 0.58, 0.6, 0.18, 0.9, 0.24, 1.53, 0.49, 6.93, 0.27, 2.63, 0.01, 0.08, 0.01, 0.19, 0.44, 0.75, 2.85],
    "Field-scale DRP Loading in Surface Runoff": [0.17, 0.43, 0.003, 0.08, 0.001, 0.013, 0.01, 0.08, 0.26, 0.34, 0.11, 0.21, 0.18, 0.24, 0.15, 0.38, 0.009, 0.12, 0.22, 0.95, 0.52, 7.84, 3.32, 7.84, 0.39, 0.35],
    "Field-scale DRP Loading in Tile Flow": [0.21, 0.53, 0.008, 0.152, 0.01, 0.12, 0.017, 0.023, 0.06, 0.28, 0.14, 0.32, 0.19, 0.55, 0.24, 0.51, 0.02, 0.2, 0.01, 0.03, 0.003, 0.104, 0.19, 6.28, 0.18, 0.9, 0.27, 2.43, 0.28, 0.34, 0.06, 0.69, 0.22, 0.95, 0.36, 5.86, 0.13, 2.08, 0.01, 0.06, 0.01, 0.15, 0.36, 0.61, 0.89, 0.79, 0.68, 0.344, 0.383],
    "Field-scale PP Loading in Surface Runoff": [0.08, 0.73, 0.04, 0.51, 0.008, 0.102, 0.07, 0.2, 0.46, 0.99, 0.14, 0.29, 0.23, 0.58, 0.17, 0.47, 1.29, 1.14],
    "Field-scale PP Loading in Tile Flow": [0.09, 1.77, 0.1, 1.33, 0.19, 1.82, 0.15, 0.23, 0.33, 0.64, 0.23, 1.15, 0.24, 1.27, 0.17, 0.98, 0.46, 1.46, 2.11, 3.14],
    "Watershed-scale TP Loading in Surface Runoff": [0.94, 0.52, 1.85, 0.18, 1.8, 0.77, 1.11, 0.99, 1.85, 1.1, 3.3],
    "Watershed-scale TP Loading in Tile Flow": [0.28, 0.92, 0.003, 0.322, 0.18],
    "Watershed-scale DRP Loading in Surface Runoff": [0.1, 0.15, 0.33, 1.26, 0.471, 0.05, 0.13, 0.34, 0.051, 0.34, 0.82, 0.63],
    "Watershed-scale DRP Loading in Tile Flow": [0.22, 0.84, 0.11, 0.23, 0.002, 0.248, 0.1, 0.017, 0.023],
}

# Assign two colors: blue for Field-scale, green for Watershed-scale
colors = ['skyblue' if 'Field' in key else 'lightgreen' for key in data.keys()]

# Get the number of data points (n values)
n_values = [len(values) for values in data.values()]
labels_with_n = [f"{key}\n(n={n})" for key, n in zip(data.keys(), n_values)]

# Calculate distribution statistics
statistics = {}
for key, values in data.items():
    values = np.array(values)
    statistics[key] = {
        "Minimum": np.min(values),
        "Lower Quartile (Q1)": np.percentile(values, 25),
        "Median": np.median(values),
        "Upper Quartile (Q3)": np.percentile(values, 75),
        "Maximum": np.max(values),
    }

# Print the statistics
print("Distribution Statistics:")
for key, stats in statistics.items():
    print(f"\n{key}:")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value:.3f}")

# Create horizontal box plots
fig, ax = plt.subplots(figsize=(12, 10))
box = ax.boxplot(data.values(), patch_artist=True, vert=False, labels=labels_with_n)

# Apply colors to the boxes
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Customize the plot
ax.set_title("(a) Phosphorus Loadings (kg/ha) from Tile-Drained Fields and Watersheds", fontsize=14, fontweight="bold")
ax.set_xlabel("Loading Values (kg/ha)", fontsize=14)
ax.grid(axis="x", linestyle="--", alpha=0.7)
ax.tick_params(axis='y', labelsize=12)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# Distribution Statistics:
#
# Field-scale TP Loading in Surface Runoff:
#   Minimum: 0.010
#   Lower Quartile (Q1): 0.220
#   Median: 0.480
#   Upper Quartile (Q3): 1.035
#   Maximum: 8.910
#
# Field-scale TP Loading in Tile Flow:
#   Minimum: 0.010
#   Lower Quartile (Q1): 0.250
#   Median: 0.640
#   Upper Quartile (Q3): 1.500
#   Maximum: 8.360
#
# Field-scale DRP Loading in Surface Runoff:
#   Minimum: 0.001
#   Lower Quartile (Q1): 0.087
#   Median: 0.215
#   Upper Quartile (Q3): 0.388
#   Maximum: 7.840
#
# Field-scale DRP Loading in Tile Flow:
#   Minimum: 0.003
#   Lower Quartile (Q1): 0.060
#   Median: 0.220
#   Upper Quartile (Q3): 0.530
#   Maximum: 6.280
#
# Field-scale PP Loading in Surface Runoff:
#   Minimum: 0.008
#   Lower Quartile (Q1): 0.112
#   Median: 0.260
#   Upper Quartile (Q3): 0.562
#   Maximum: 1.290
#
# Field-scale PP Loading in Tile Flow:
#   Minimum: 0.090
#   Lower Quartile (Q1): 0.220
#   Median: 0.550
#   Upper Quartile (Q3): 1.363
#   Maximum: 3.140
#
# Watershed-scale TP Loading in Surface Runoff:
#   Minimum: 0.180
#   Lower Quartile (Q1): 0.855
#   Median: 1.100
#   Upper Quartile (Q3): 1.825
#   Maximum: 3.300
#
# Watershed-scale TP Loading in Tile Flow:
#   Minimum: 0.003
#   Lower Quartile (Q1): 0.180
#   Median: 0.280
#   Upper Quartile (Q3): 0.322
#   Maximum: 0.920
#
# Watershed-scale DRP Loading in Surface Runoff:
#   Minimum: 0.050
#   Lower Quartile (Q1): 0.122
#   Median: 0.335
#   Upper Quartile (Q3): 0.511
#   Maximum: 1.260
#
# Watershed-scale DRP Loading in Tile Flow:
#   Minimum: 0.002
#   Lower Quartile (Q1): 0.023
#   Median: 0.110
#   Upper Quartile (Q3): 0.230
#   Maximum: 0.840

# %%
import matplotlib.pyplot as plt
import numpy as np

# New data for box plots
data = {
    "Field-scale NO3-N Loading in Tile Flow": [3.1, 3.8, 1, 18.4, 3.6, 15.4, 24.63, 43.76, 0.67, 5.88, 2.88, 8.34, 5.71, 42.95, 23.9, 56.8, 2.9, 153, 17, 37],
    "Field-scale TN Loading in Tile Flow": [34.73, 52.86, 2.09, 20.63, 28.3, 64.2, 6.6, 97.7],
    "Watershed-scale NO3-N Loading in Surface Runoff": [9.15, 11.55, 15.54, 5.27, 4.67, 2.4, 2.6, 1.5],
    "Watershed-scale NO3-N Loading in Tile Flow": [22.8, 27.36, 6.5],
    "Watershed-scale TN Loading in Surface Runoff": [0.93, 6.4, 6, 9.9, 16.35, 15.11],
}

# Assign two colors: blue for Field-scale, green for Watershed-scale
colors = ['skyblue' if 'Field-scale' in key else 'lightgreen' for key in data.keys()]

# Get the number of data points (n values)
n_values = [len(values) for values in data.values()]
labels_with_n = [f"{key}\n(n={n})" for key, n in zip(data.keys(), n_values)]

# Calculate distribution statistics
statistics = {}
for key, values in data.items():
    values = np.array(values)
    statistics[key] = {
        "Minimum": np.min(values),
        "Lower Quartile (Q1)": np.percentile(values, 25),
        "Median": np.median(values),
        "Upper Quartile (Q3)": np.percentile(values, 75),
        "Maximum": np.max(values),
    }

# Print the statistics
print("Distribution Statistics:")
for key, stats in statistics.items():
    print(f"\n{key}:")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value:.3f}")

# Create horizontal box plots
fig, ax = plt.subplots(figsize=(12, 8))
box = ax.boxplot(data.values(), patch_artist=True, vert=False, labels=labels_with_n)

# Apply colors to the boxes
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Customize the plot
ax.set_title("(b) Nitrogen Loadings (kg/ha) from Tile-Drained Fields and Watersheds", fontsize=14, fontweight="bold")
ax.set_xlabel("Loading Values (kg/ha)", fontsize=14)
ax.grid(axis="x", linestyle="--", alpha=0.7)
ax.tick_params(axis='y', labelsize=12)

# Add a legend outside the plot
ax.legend([box['boxes'][0], box['boxes'][-1]], ['Field-scale', 'Watershed-scale'], 
          loc='upper center', bbox_to_anchor=(0.5, -0.1), fontsize=12, frameon=False, ncol=2)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# Distribution Statistics:
#
# Field-scale NO3-N Loading in Tile Flow:
#   Minimum: 0.670
#   Lower Quartile (Q1): 3.475
#   Median: 11.870
#   Upper Quartile (Q3): 27.723
#   Maximum: 153.000
#
# Field-scale TN Loading in Tile Flow:
#   Minimum: 2.090
#   Lower Quartile (Q1): 17.122
#   Median: 31.515
#   Upper Quartile (Q3): 55.695
#   Maximum: 97.700
#
# Watershed-scale NO3-N Loading in Surface Runoff:
#   Minimum: 1.500
#   Lower Quartile (Q1): 2.550
#   Median: 4.970
#   Upper Quartile (Q3): 9.750
#   Maximum: 15.540
#
# Watershed-scale NO3-N Loading in Tile Flow:
#   Minimum: 6.500
#   Lower Quartile (Q1): 14.650
#   Median: 22.800
#   Upper Quartile (Q3): 25.080
#   Maximum: 27.360
#
# Watershed-scale TN Loading in Surface Runoff:
#   Minimum: 0.930
#   Lower Quartile (Q1): 6.100
#   Median: 8.150
#   Upper Quartile (Q3): 13.807
#   Maximum: 16.350

# %%
import matplotlib.pyplot as plt
import numpy as np

# Grouped data for management strategies
data = {
    "Management at the source": {
        "Nitrogen (NO3-N and TN) loads\n reduction potential %": [3.5, 13.7, 14, 16, 67, 27, 72, 69, 90, 21, 38, 14, 16, 43.6, 48.6, 59, 62, 43],
        "Phosphorus (TP, DRP, and PP) loads\n reduction potential %": [4.3, 25.4, 18, 10, 53.98, 48.12, 7, 58, 31, 30],
    },
    "Control at the edge-of-field": {
        "Nitrogen (NO3-N) loads\n reduction potential %": [30.5, 33.61, 38, 39, 26, 43, 47, 48, 28, 52, 71, 85, 37, 46, 8, 84],
        "Phosphorus (TP and DRP) loads\n reduction potential %": [23, 55, 40, 68, 57],
    },
    "Watershed management with a combination of BMPs": {
        "Overall nutrient loads\n reduction potential %": [80, 55.8, 38.5, 22, 31, 67],
    },
}

# Colors for each nutrient
nutrient_colors = {
    "Nitrogen (NO3-N and TN) loads\n reduction potential %": "skyblue",
    "Phosphorus (TP, DRP, and PP) loads\n reduction potential %": "lightgreen",
    "Nitrogen (NO3-N) loads\n reduction potential %": "skyblue",
    "Phosphorus (TP and DRP) loads\n reduction potential %": "lightgreen",
    "Overall nutrient loads\n reduction potential %": "lightgoldenrodyellow",  # For watershed management
}

# Create subplots for the strategies
fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True)  # 3 horizontal subplots

# Dictionary to store statistics
statistics = {}

# Loop through each strategy and create individual horizontal box plots
for ax, (strategy, nutrients) in zip(axes, data.items()):
    # Extract nutrient types and values
    nutrient_names = list(nutrients.keys())
    nutrient_values = list(nutrients.values())
    
    # Get the number of data points (n values)
    n_values = [len(values) for values in nutrient_values]
    labels_with_n = [f"{name}\n(n={n})" for name, n in zip(nutrient_names, n_values)]
    
    # Calculate distribution statistics
    for nutrient_name, values in zip(nutrient_names, nutrient_values):
        values = np.array(values)
        statistics[nutrient_name] = {
            "Minimum": np.min(values),
            "Lower Quartile (Q1)": np.percentile(values, 25),
            "Median": np.median(values),
            "Upper Quartile (Q3)": np.percentile(values, 75),
            "Maximum": np.max(values),
        }
    
    # Create horizontal boxplot
    box = ax.boxplot(
        nutrient_values,
        patch_artist=True,
        labels=labels_with_n,
        vert=False,  # Horizontal boxplot
    )
    
    # Apply colors to the boxes based on the nutrient type
    for patch, nutrient_name in zip(box["boxes"], nutrient_names):
        patch.set_facecolor(nutrient_colors[nutrient_name])
    
    # Customize the subplot
    ax.set_title(strategy, fontsize=14, fontweight="bold", pad=10)
    ax.set_yticklabels(labels_with_n, fontsize=12)

# Adjust layout for clarity
plt.tight_layout()

# Show the plots
plt.show()

# Print the statistics
print("Distribution Statistics:")
for nutrient, stats in statistics.items():
    print(f"\n{nutrient}:")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value:.3f}")
# Out:
# Distribution Statistics:
#
# Nitrogen (NO3-N and TN) loads
#  reduction potential %:
#   Minimum: 3.500
#   Lower Quartile (Q1): 16.000
#   Median: 40.500
#   Upper Quartile (Q3): 61.250
#   Maximum: 90.000
#
# Phosphorus (TP, DRP, and PP) loads
#  reduction potential %:
#   Minimum: 4.300
#   Lower Quartile (Q1): 12.000
#   Median: 27.700
#   Upper Quartile (Q3): 43.840
#   Maximum: 58.000
#
# Nitrogen (NO3-N) loads
#  reduction potential %:
#   Minimum: 8.000
#   Lower Quartile (Q1): 32.832
#   Median: 41.000
#   Upper Quartile (Q3): 49.000
#   Maximum: 85.000
#
# Phosphorus (TP and DRP) loads
#  reduction potential %:
#   Minimum: 23.000
#   Lower Quartile (Q1): 40.000
#   Median: 55.000
#   Upper Quartile (Q3): 57.000
#   Maximum: 68.000
#
# Overall nutrient loads
#  reduction potential %:
#   Minimum: 22.000
#   Lower Quartile (Q1): 32.875
#   Median: 47.150
#   Upper Quartile (Q3): 64.200
#   Maximum: 80.000

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Grouped data for management strategies
data = {
    "Management at the source": {
        "Nitrogen (NO3-N and TN) loads\n reduction potential %": [3.5, 13.7, 14, 16, 67, 27, 72, 69, 90, 21, 38, 14, 16, 43.6, 48.6, 59, 62, 43],
        "Phosphorus (TP, DRP, and PP) loads\n reduction potential %": [4.3, 25.4, 18, 10, 53.98, 48.12, 7, 58, 31, 30],
    },
    "Control at the edge-of-field": {
        "Nitrogen (NO3-N) loads\n reduction potential %": [30.5, 33.61, 38, 39, 26, 43, 47, 48, 28, 52, 71, 85, 37, 46, 8, 84],
        "Phosphorus (TP and DRP) loads\n reduction potential %": [23, 55, 40, 68, 57],
    },
    "Watershed management with a combination of BMPs": {
        "Overall nutrient loads\n reduction potential %": [80, 55.8, 38.5, 22, 31, 67],
    },
}


# Function to perform Monte Carlo simulation for a dataset
def monte_carlo_simulation(values, n_simulations=10000):
    # Fit a normal distribution
    mean, std = np.mean(values), np.std(values)
    simulated_values = np.random.normal(mean, std, size=n_simulations)
    
    # Calculate confidence intervals
    ci_lower = np.percentile(simulated_values, 2.5)
    ci_upper = np.percentile(simulated_values, 97.5)
    
    return simulated_values, ci_lower, ci_upper, mean, std

# Visualization: Monte Carlo histograms and confidence intervals
fig, axes = plt.subplots(3, 1, figsize=(10, 18))  # One subplot per management strategy

# Dictionary to store statistics for each nutrient
statistics = {}

for ax, (strategy, nutrients) in zip(axes, data.items()):
    ax.set_title(strategy, fontsize=14, fontweight="bold", pad=10)
    ax.set_xlabel("Reduction Potential (%)", fontsize=12)
    ax.set_ylabel("Frequency", fontsize=12)
    ax.grid(axis="y", linestyle="--", alpha=0.7)

    for nutrient, values in nutrients.items():
        # Perform Monte Carlo simulation
        simulated, ci_lower, ci_upper, mean, std = monte_carlo_simulation(values)
        
        # Save statistics for reporting
        statistics[nutrient] = {
            "Mean": mean,
            "Standard Deviation": std,
            "95% Confidence Interval": (ci_lower, ci_upper),
        }
        
        # Plot histogram
        ax.hist(simulated, bins=30, alpha=0.6, 
                label=f"{nutrient}\nMean: {mean:.2f}, 95% CI: [{ci_lower:.2f}, {ci_upper:.2f}]")
        
    # Add legend
    ax.legend(loc="upper right", fontsize=10)

# Adjust layout and show the plot
fig.suptitle("Monte Carlo Simulation: Nutrient Load Reduction Potential", fontsize=16, fontweight="bold")
plt.tight_layout()
plt.subplots_adjust(top=0.9)
plt.show()

# Print the statistics
print("Monte Carlo Simulation Statistics:")
for nutrient, stats in statistics.items():
    print(f"\n{nutrient}:")
    print(f"  Mean: {stats['Mean']:.2f}")
    print(f"  Standard Deviation: {stats['Standard Deviation']:.2f}")
    print(f"  95% Confidence Interval: [{stats['95% Confidence Interval'][0]:.2f}, {stats['95% Confidence Interval'][1]:.2f}]")
# Out:
# Monte Carlo Simulation Statistics:
#
# Nitrogen (NO3-N and TN) loads
#  reduction potential %:
#   Mean: 39.86
#   Standard Deviation: 24.83
#   95% Confidence Interval: [-8.13, 89.89]
#
# Phosphorus (TP, DRP, and PP) loads
#  reduction potential %:
#   Mean: 28.58
#   Standard Deviation: 18.50
#   95% Confidence Interval: [-8.50, 65.19]
#
# Nitrogen (NO3-N) loads
#  reduction potential %:
#   Mean: 44.76
#   Standard Deviation: 19.95
#   95% Confidence Interval: [5.42, 83.48]
#
# Phosphorus (TP and DRP) loads
#  reduction potential %:
#   Mean: 48.60
#   Standard Deviation: 15.60
#   95% Confidence Interval: [17.64, 78.62]
#
# Overall nutrient loads
#  reduction potential %:
#   Mean: 49.05
#   Standard Deviation: 20.39
#   95% Confidence Interval: [8.70, 88.85]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the Monte Carlo simulation
# Tile flow as percentage of annual precipitation
field_scale_precipitation = [16, 41, 26, 66, 11, 40, 17, 22, 13.7, 21.9, 17.5, 32]
watershed_scale_precipitation = [8.5, 16.2, 13, 19, 34.14, 45]

# Tile flow as percentage of total flow
field_scale_total_flow = [78, 90, 80, 97, 81, 96, 83, 90]
watershed_scale_total_flow = [42, 53, 80, 40, 45, 47]

# Combine the data for simulation
data = [
    ("Field scale: % of Precipitation", field_scale_precipitation),
    ("Watershed scale: % of Precipitation", watershed_scale_precipitation),
    ("Field scale: % of Total Flow", field_scale_total_flow),
    ("Watershed scale: % of Total Flow", watershed_scale_total_flow),
]

# Colors: One shade of blue for Precipitation, another for Total Flow
colors = ['#87ceeb', '#87ceeb', '#4682b4', '#4682b4']  # Sky blue for precipitation, steel blue for flow

# Function to perform Monte Carlo simulation
def monte_carlo_simulation(values, n_simulations=10000):
    # Fit a normal distribution
    mean, std = np.mean(values), np.std(values)
    simulated_values = np.random.normal(mean, std, size=n_simulations)
    
    # Calculate confidence intervals
    ci_lower = np.percentile(simulated_values, 2.5)
    ci_upper = np.percentile(simulated_values, 97.5)
    
    return simulated_values, ci_lower, ci_upper, mean, std

# Dictionary to store statistics
statistics = {}

# Monte Carlo simulation and visualization
fig, ax = plt.subplots(figsize=(12, 6))

for i, (label, values) in enumerate(data):
    # Perform Monte Carlo simulation
    simulated, ci_lower, ci_upper, mean, std = monte_carlo_simulation(values)
    
    # Store statistics
    statistics[label] = {
        "Mean": mean,
        "Standard Deviation": std,
        "95% Confidence Interval": (ci_lower, ci_upper),
    }
    
    # Plot histogram for Monte Carlo simulations
    ax.hist(simulated, bins=30, alpha=0.6, label=f"{label}\nMean: {mean:.2f}, 95% CI: [{ci_lower:.2f}, {ci_upper:.2f}]", color=colors[i])

# Customize the plot
ax.set_title("Monte Carlo Simulation: Tile Flow as Percentage of Precipitation and Total Flow", fontsize=14)
ax.set_xlabel("Percentage (%)", fontsize=12)
ax.set_ylabel("Frequency", fontsize=12)
ax.grid(axis="y", linestyle="--", alpha=0.7)
ax.legend(loc="upper right", fontsize=10, frameon=False)

# Show the plot
plt.tight_layout()
plt.show()

# Print the statistics
print("Monte Carlo Simulation Statistics:")
for label, stats in statistics.items():
    print(f"\n{label}:")
    print(f"  Mean: {stats['Mean']:.2f}")
    print(f"  Standard Deviation: {stats['Standard Deviation']:.2f}")
    print(f"  95% Confidence Interval: [{stats['95% Confidence Interval'][0]:.2f}, {stats['95% Confidence Interval'][1]:.2f}]")
# Out:
# Monte Carlo Simulation Statistics:
#
# Field scale: % of Precipitation:
#   Mean: 27.01
#   Standard Deviation: 15.02
#   95% Confidence Interval: [-2.09, 56.76]
#
# Watershed scale: % of Precipitation:
#   Mean: 22.64
#   Standard Deviation: 12.78
#   95% Confidence Interval: [-2.61, 47.59]
#
# Field scale: % of Total Flow:
#   Mean: 86.88
#   Standard Deviation: 6.90
#   95% Confidence Interval: [73.55, 100.14]
#
# Watershed scale: % of Total Flow:
#   Mean: 51.17
#   Standard Deviation: 13.53
#   95% Confidence Interval: [25.54, 77.84]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the Monte Carlo simulation
# Tile flow as percentage of annual precipitation
field_scale_precipitation = [16, 41, 26, 66, 11, 40, 17, 22, 13.7, 21.9, 17.5, 32]
watershed_scale_precipitation = [8.5, 16.2, 13, 19, 34.14, 45]

# Tile flow as percentage of total flow
field_scale_total_flow = [78, 90, 80, 97, 81, 96, 83, 90]
watershed_scale_total_flow = [42, 53, 80, 40, 45, 47]

# Combine the data for simulation
data = [
    ("Field scale: % of Precipitation", field_scale_precipitation),
    ("Watershed scale: % of Precipitation", watershed_scale_precipitation),
    ("Field scale: % of Total Flow", field_scale_total_flow),
    ("Watershed scale: % of Total Flow", watershed_scale_total_flow),
]

# Colors: One shade of blue for Precipitation, another for Total Flow
colors = ['#87ceeb', '#87ceeb', '#4682b4', '#4682b4']  # Sky blue for precipitation, steel blue for flow

# Function to perform Monte Carlo simulation with log-normal distribution
def monte_carlo_simulation_log_normal(values, n_simulations=10000):
    # Fit a log-normal distribution
    log_values = np.log(values)
    mean, std = np.mean(log_values), np.std(log_values)
    simulated_values = np.random.lognormal(mean, std, size=n_simulations)
    
    # Calculate confidence intervals
    ci_lower = np.percentile(simulated_values, 2.5)
    ci_upper = np.percentile(simulated_values, 97.5)
    
    return simulated_values, ci_lower, ci_upper, np.exp(mean), np.exp(mean + std)

# Dictionary to store statistics
statistics = {}

# Monte Carlo simulation and visualization
fig, ax = plt.subplots(figsize=(12, 6))

for i, (label, values) in enumerate(data):
    # Perform Monte Carlo simulation using log-normal distribution
    simulated, ci_lower, ci_upper, mean, std = monte_carlo_simulation_log_normal(values)
    
    # Store statistics
    statistics[label] = {
        "Mean (Exp)": mean,
        "Standard Deviation (Exp)": std,
        "95% Confidence Interval": (ci_lower, ci_upper),
    }
    
    # Plot histogram for Monte Carlo simulations
    ax.hist(simulated, bins=30, alpha=0.6, label=f"{label}\nMean: {mean:.2f}, 95% CI: [{ci_lower:.2f}, {ci_upper:.2f}]", color=colors[i])

# Customize the plot
ax.set_title("Monte Carlo Simulation (Log-Normal): Tile Flow as Percentage of Precipitation and Total Flow", fontsize=14)
ax.set_xlabel("Percentage (%)", fontsize=12)
ax.set_ylabel("Frequency", fontsize=12)
ax.grid(axis="y", linestyle="--", alpha=0.7)
ax.legend(loc="upper right", fontsize=10, frameon=False)

# Show the plot
plt.tight_layout()
plt.show()

# Print the statistics
print("Monte Carlo Simulation Statistics (Log-Normal):")
for label, stats in statistics.items():
    print(f"\n{label}:")
    print(f"  Mean (Exp): {stats['Mean (Exp)']:.2f}")
    print(f"  Standard Deviation (Exp): {stats['Standard Deviation (Exp)']:.2f}")
    print(f"  95% Confidence Interval: [{stats['95% Confidence Interval'][0]:.2f}, {stats['95% Confidence Interval'][1]:.2f}]")
# Out:
# Monte Carlo Simulation Statistics (Log-Normal):
#
# Field scale: % of Precipitation:
#   Mean (Exp): 23.68
#   Standard Deviation (Exp): 38.98
#   95% Confidence Interval: [8.90, 63.53]
#
# Watershed scale: % of Precipitation:
#   Mean (Exp): 19.34
#   Standard Deviation (Exp): 33.95
#   95% Confidence Interval: [6.30, 57.61]
#
# Field scale: % of Total Flow:
#   Mean (Exp): 86.60
#   Standard Deviation (Exp): 93.72
#   95% Confidence Interval: [74.21, 101.01]
#
# Watershed scale: % of Total Flow:
#   Mean (Exp): 49.70
#   Standard Deviation (Exp): 62.59
#   95% Confidence Interval: [31.78, 78.07]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the box plots
# Tile flow as percentage of annual precipitation
field_scale_precipitation = [16, 41, 26, 66, 11, 40, 17, 22, 13.7, 21.9, 17.5, 32]
watershed_scale_precipitation = [8.5, 16.2, 13, 19, 34.14, 45]

# Tile flow as percentage of total flow
field_scale_total_flow = [78, 90, 80, 97, 81, 96, 83, 90]
watershed_scale_total_flow = [42, 53, 80, 40, 45, 47]

# Combine the data for the single plot
data = [
    field_scale_precipitation, 
    watershed_scale_precipitation, 
    field_scale_total_flow, 
    watershed_scale_total_flow
]

# Number of values for each dataset
n_values = [
    len(field_scale_precipitation), 
    len(watershed_scale_precipitation), 
    len(field_scale_total_flow), 
    len(watershed_scale_total_flow)
]

# Labels for the boxplot groups (including n= values)
labels = [
    f"Field scale: % of Precipitation\n(n={n_values[0]})",
    f"Watershed scale: % of Precipitation\n(n={n_values[1]})",
    f"Field scale: % of Total Flow\n(n={n_values[2]})",
    f"Watershed scale: % of Total Flow\n(n={n_values[3]})"
]

# Colors: One shade of blue for Precipitation, another for Total Flow
colors = ['#87ceeb', '#87ceeb', '#4682b4', '#4682b4']  # Sky blue for precipitation, steel blue for flow

# Dictionary to store statistics
statistics = {}

# Calculate statistics for each dataset
for label, dataset in zip(labels, data):
    dataset = np.array(dataset)
    statistics[label] = {
        "Minimum": np.min(dataset),
        "Lower Quartile (Q1)": np.percentile(dataset, 25),
        "Median": np.median(dataset),
        "Upper Quartile (Q3)": np.percentile(dataset, 75),
        "Maximum": np.max(dataset),
    }

# Create the boxplot
fig, ax = plt.subplots(figsize=(12, 6))
box = ax.boxplot(data, patch_artist=True, labels=labels)

# Apply colors to the boxes
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Add title and axis labels
plt.title("Tile Flow as Percentage of Annual Precipitation and Total Flow", fontsize=14)
plt.ylabel("Percentage (%)", fontsize=12)
plt.xticks(fontsize=12)  # Ensure no rotation for x-axis tick labels
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Add a legend for color distinction
plt.legend([box['boxes'][0], box['boxes'][2]], 
           ['Precipitation', 'Total Flow'], 
           loc='upper right', fontsize=10, frameon=False)

# Show the plot
plt.tight_layout()
plt.show()

# Print the statistics
print("Box Plot Statistics:")
for label, stats in statistics.items():
    print(f"\n{label}:")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value:.2f}")
# Out:
# Box Plot Statistics:
#
# Field scale: % of Precipitation
# (n=12):
#   Minimum: 11.00
#   Lower Quartile (Q1): 16.75
#   Median: 21.95
#   Upper Quartile (Q3): 34.00
#   Maximum: 66.00
#
# Watershed scale: % of Precipitation
# (n=6):
#   Minimum: 8.50
#   Lower Quartile (Q1): 13.80
#   Median: 17.60
#   Upper Quartile (Q3): 30.36
#   Maximum: 45.00
#
# Field scale: % of Total Flow
# (n=8):
#   Minimum: 78.00
#   Lower Quartile (Q1): 80.75
#   Median: 86.50
#   Upper Quartile (Q3): 91.50
#   Maximum: 97.00
#
# Watershed scale: % of Total Flow
# (n=6):
#   Minimum: 40.00
#   Lower Quartile (Q1): 42.75
#   Median: 46.00
#   Upper Quartile (Q3): 51.50
#   Maximum: 80.00

# %%
import matplotlib.pyplot as plt

# Grouped data for management strategies
data = {
    "Management at the source": {
        "Nitrogen\n reduction potential %": [3.5, 13.7, 14, 16, 67, 27, 72, 69, 90, 21, 38, 14, 16, 43.6, 48.6, 59, 62, 43],
        "Phosphorus\n reduction potential %": [4.3, 25.4, 18, 10, 53.98, 48.12, 7, 58, 31, 30],
    },
    "Control at the edge-of-field": {
        "Nitrogen\n reduction potential %": [30.5, 33.61, 38, 39, 26, 43, 47, 48, 28, 52, 71, 85, 37, 46, 8, 84],
        "Phosphorus\n reduction potential %": [23, 55, 40, 68, 57],
    },
    "Watershed management with a combination of BMPs": {
        "Overall nutrient\n reduction potential %": [80, 55.8, 38.5, 22, 31, 67],
    },
}

# Colors for each nutrient
nutrient_colors = {
    "Nitrogen\n reduction potential %": "skyblue",
    "Phosphorus\n reduction potential %": "lightgreen",
    "Nitrogen\n reduction potential %": "skyblue",
    "Phosphorus\n reduction potential %": "lightgreen",
    "Overall nutrient\n reduction potential %": "lightgoldenrodyellow",  # For watershed management
}

# Create subplots for the strategies
fig, axes = plt.subplots(3, 1, figsize=(12, 14), sharex=True)  # 3 horizontal subplots

# Loop through each strategy and create individual horizontal box plots
for ax, (strategy, nutrients) in zip(axes, data.items()):
    # Extract nutrient types and values
    nutrient_names = list(nutrients.keys())
    nutrient_values = list(nutrients.values())
    
    # Get the number of data points (n values)
    n_values = [len(values) for values in nutrient_values]
    labels_with_n = [f"{name}\n(n={n})" for name, n in zip(nutrient_names, n_values)]
    
    # Create horizontal boxplot
    box = ax.boxplot(
        nutrient_values,
        patch_artist=True,
        labels=labels_with_n,
        vert=False,  # Horizontal boxplot
    )
    
    # Apply colors to the boxes based on the nutrient type
    for patch, nutrient_name in zip(box["boxes"], nutrient_names):
        patch.set_facecolor(nutrient_colors[nutrient_name])
    
    # Customize the subplot
    ax.set_title(strategy, fontsize=18, fontweight="bold", pad=10)
    ax.set_yticklabels(labels_with_n, fontsize=16, fontweight="bold")  # Make y-axis labels bold

# Adjust x-axis settings for bold labels
for ax in axes:
    ax.tick_params(axis='x', labelsize=12)
    for label in ax.get_xticklabels():
        label.set_fontweight("bold")  # Make x-axis labels bold

# Adjust layout for clarity
plt.tight_layout()

# Show the plots
plt.show()

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale TP Loading in Surface Runoff": [0.4, 1.9, 0.05, 0.56, 0.01, 0.13, 0.08, 0.25, 0.51, 1.38, 0.45, 0.89, 0.37, 0.92, 0.02, 0.34, 0.6, 4.55, 3.32, 8.91],
    "Field-scale TP Loading in Tile Flow": [0.3, 2.3, 0.14, 1.62, 0.21, 2.14, 0.17, 0.26, 0.6, 0.93, 0.64, 1.47, 0.66, 1.34, 0.58, 1.47, 0.15, 0.72, 0.01, 0.46, 0.73, 8.36, 2.02, 3.21, 1.04, 3.45, 0.58, 0.6, 0.18, 0.9, 0.24, 1.53, 0.49, 6.93, 0.27, 2.63, 0.01, 0.08, 0.01, 0.19, 0.44, 0.75, 2.85],
    "Field-scale DRP Loading in Surface Runoff": [0.17, 0.43, 0.003, 0.08, 0.001, 0.013, 0.01, 0.08, 0.26, 0.34, 0.11, 0.21, 0.18, 0.24, 0.15, 0.38, 0.009, 0.12, 0.22, 0.95, 0.52, 7.84, 3.32, 7.84, 0.39, 0.35],
    "Field-scale DRP Loading in Tile Flow": [0.21, 0.53, 0.008, 0.152, 0.01, 0.12, 0.017, 0.023, 0.06, 0.28, 0.14, 0.32, 0.19, 0.55, 0.24, 0.51, 0.02, 0.2, 0.01, 0.03, 0.003, 0.104, 0.19, 6.28, 0.18, 0.9, 0.27, 2.43, 0.28, 0.34, 0.06, 0.69, 0.22, 0.95, 0.36, 5.86, 0.13, 2.08, 0.01, 0.06, 0.01, 0.15, 0.36, 0.61, 0.89, 0.79, 0.68, 0.344, 0.383],
    "Field-scale PP Loading in Surface Runoff": [0.08, 0.73, 0.04, 0.51, 0.008, 0.102, 0.07, 0.2, 0.46, 0.99, 0.14, 0.29, 0.23, 0.58, 0.17, 0.47, 1.29, 1.14],
    "Field-scale PP Loading in Tile Flow": [0.09, 1.77, 0.1, 1.33, 0.19, 1.82, 0.15, 0.23, 0.33, 0.64, 0.23, 1.15, 0.24, 1.27, 0.17, 0.98, 0.46, 1.46, 2.11, 3.14],
    "Watershed-scale TP Loading in Surface Runoff": [0.94, 0.52, 1.85, 0.18, 1.8, 0.77, 1.11, 0.99, 1.85, 1.1, 3.3],
    "Watershed-scale TP Loading in Tile Flow": [0.28, 0.92, 0.003, 0.322, 0.18],
    "Watershed-scale DRP Loading in Surface Runoff": [0.1, 0.15, 0.33, 1.26, 0.471, 0.05, 0.13, 0.34, 0.051, 0.34, 0.82, 0.63],
    "Watershed-scale DRP Loading in Tile Flow": [0.22, 0.84, 0.11, 0.23, 0.002, 0.248, 0.1, 0.017, 0.023],
}

# Perform Monte Carlo Simulation for each dataset
results = {}
for key, values in data.items():
    # Fit a log-normal distribution (appropriate for environmental data)
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    
    # Generate 10,000 random samples
    simulated_samples = stats.lognorm.rvs(shape, loc, scale, size=10000)
    
    # Calculate statistics
    ci_lower = np.percentile(simulated_samples, 2.5)
    ci_upper = np.percentile(simulated_samples, 97.5)
    mean = np.mean(simulated_samples)
    median = np.median(simulated_samples)
    std_dev = np.std(simulated_samples)
    
    # Store results
    results[key] = {
        "mean": mean,
        "median": median,
        "std_dev": std_dev,
        "ci_lower": ci_lower,
        "ci_upper": ci_upper,
    }

# Print results
for key, result in results.items():
    print(f"{key}:")
    print(f"  Mean: {result['mean']:.2f}")
    print(f"  Median: {result['median']:.2f}")
    print(f"  Std Dev: {result['std_dev']:.2f}")
    print(f"  95% CI: [{result['ci_lower']:.2f}, {result['ci_upper']:.2f}]")
# Out:
# Field-scale TP Loading in Surface Runoff:
#   Mean: 1.69
#   Median: 0.42
#   Std Dev: 5.80
#   95% CI: [0.02, 11.21]
# Field-scale TP Loading in Tile Flow:
#   Mean: 1.83
#   Median: 0.56
#   Std Dev: 5.93
#   95% CI: [0.03, 11.17]
# Field-scale DRP Loading in Surface Runoff:
#   Mean: 1.34
#   Median: 0.16
#   Std Dev: 7.07
#   95% CI: [0.00, 9.50]
# Field-scale DRP Loading in Tile Flow:
#   Mean: 0.73
#   Median: 0.18
#   Std Dev: 2.49
#   95% CI: [0.01, 5.09]
# Field-scale PP Loading in Surface Runoff:
#   Mean: 0.51
#   Median: 0.23
#   Std Dev: 0.96
#   95% CI: [0.02, 2.84]
# Field-scale PP Loading in Tile Flow:
#   Mean: 0.99
#   Median: 0.53
#   Std Dev: 1.62
#   95% CI: [0.06, 4.70]
# Watershed-scale TP Loading in Surface Runoff:
#   Mean: 1.39
#   Median: 1.06
#   Std Dev: 1.18
#   95% CI: [0.25, 4.60]
# Watershed-scale TP Loading in Tile Flow:
#   Mean: 1.04
#   Median: 0.14
#   Std Dev: 7.05
#   95% CI: [0.00, 6.81]
# Watershed-scale DRP Loading in Surface Runoff:
#   Mean: 0.41
#   Median: 0.25
#   Std Dev: 0.59
#   95% CI: [0.03, 1.75]
# Watershed-scale DRP Loading in Tile Flow:
#   Mean: 0.33
#   Median: 0.07
#   Std Dev: 1.03
#   95% CI: [0.00, 2.33]

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale TP Loading in Surface Runoff": [0.4, 1.9, 0.05, 0.56, 0.01, 0.13, 0.08, 0.25, 0.51, 1.38, 0.45, 0.89, 0.37, 0.92, 0.02, 0.34, 0.6, 4.55, 3.32, 8.91],
    "Field-scale TP Loading in Tile Flow": [0.3, 2.3, 0.14, 1.62, 0.21, 2.14, 0.17, 0.26, 0.6, 0.93, 0.64, 1.47, 0.66, 1.34, 0.58, 1.47, 0.15, 0.72, 0.01, 0.46, 0.73, 8.36, 2.02, 3.21, 1.04, 3.45, 0.58, 0.6, 0.18, 0.9, 0.24, 1.53, 0.49, 6.93, 0.27, 2.63, 0.01, 0.08, 0.01, 0.19, 0.44, 0.75, 2.85],
    "Field-scale DRP Loading in Surface Runoff": [0.17, 0.43, 0.003, 0.08, 0.001, 0.013, 0.01, 0.08, 0.26, 0.34, 0.11, 0.21, 0.18, 0.24, 0.15, 0.38, 0.009, 0.12, 0.22, 0.95, 0.52, 7.84, 3.32, 7.84, 0.39, 0.35],
    "Field-scale DRP Loading in Tile Flow": [0.21, 0.53, 0.008, 0.152, 0.01, 0.12, 0.017, 0.023, 0.06, 0.28, 0.14, 0.32, 0.19, 0.55, 0.24, 0.51, 0.02, 0.2, 0.01, 0.03, 0.003, 0.104, 0.19, 6.28, 0.18, 0.9, 0.27, 2.43, 0.28, 0.34, 0.06, 0.69, 0.22, 0.95, 0.36, 5.86, 0.13, 2.08, 0.01, 0.06, 0.01, 0.15, 0.36, 0.61, 0.89, 0.79, 0.68, 0.344, 0.383],
    "Field-scale PP Loading in Surface Runoff": [0.08, 0.73, 0.04, 0.51, 0.008, 0.102, 0.07, 0.2, 0.46, 0.99, 0.14, 0.29, 0.23, 0.58, 0.17, 0.47, 1.29, 1.14],
    "Field-scale PP Loading in Tile Flow": [0.09, 1.77, 0.1, 1.33, 0.19, 1.82, 0.15, 0.23, 0.33, 0.64, 0.23, 1.15, 0.24, 1.27, 0.17, 0.98, 0.46, 1.46, 2.11, 3.14],
    "Watershed-scale TP Loading in Surface Runoff": [0.94, 0.52, 1.85, 0.18, 1.8, 0.77, 1.11, 0.99, 1.85, 1.1, 3.3],
    "Watershed-scale TP Loading in Tile Flow": [0.28, 0.92, 0.003, 0.322, 0.18],
    "Watershed-scale DRP Loading in Surface Runoff": [0.1, 0.15, 0.33, 1.26, 0.471, 0.05, 0.13, 0.34, 0.051, 0.34, 0.82, 0.63],
    "Watershed-scale DRP Loading in Tile Flow": [0.22, 0.84, 0.11, 0.23, 0.002, 0.248, 0.1, 0.017, 0.023],
}

# Perform Monte Carlo Simulation for each dataset
results = {}
for key, values in data.items():
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    simulated_samples = stats.lognorm.rvs(shape, loc, scale, size=10000)
    ci_lower = np.percentile(simulated_samples, 2.5)
    ci_upper = np.percentile(simulated_samples, 97.5)
    mean = np.mean(simulated_samples)
    median = np.median(simulated_samples)
    std_dev = np.std(simulated_samples)
    results[key] = {
        "mean": mean,
        "median": median,
        "std_dev": std_dev,
        "ci_lower": ci_lower,
        "ci_upper": ci_upper,
    }

# Extract results for plotting
categories = list(results.keys())
all_means = [results[key]["mean"] for key in categories]
all_medians = [results[key]["median"] for key in categories]
all_ci_lowers = [results[key]["ci_lower"] for key in categories]
all_ci_uppers = [results[key]["ci_upper"] for key in categories]

# Plot the results
fig, ax = plt.subplots(figsize=(12, 8))

# Add error bars for mean ± 95% CI
for i, (mean, ci_lower, ci_upper) in enumerate(zip(all_means, all_ci_lowers, all_ci_uppers)):
    ax.errorbar(x=mean, y=i, xerr=[[mean - ci_lower], [ci_upper - mean]], fmt='o', color='blue', label='Mean ± 95% CI' if i == 0 else "", capsize=5)

# Add medians as scatter points
ax.scatter(all_medians, range(len(categories)), color='red', label='Median', zorder=3)

# Add labels and formatting
ax.set_yticks(range(len(categories)))
ax.set_yticklabels(categories, fontsize=10)
ax.set_xlabel("Loading Values (kg/ha)", fontsize=12)
ax.set_title("Monte Carlo Simulation Results: Means and 95% CIs", fontsize=14, fontweight='bold')
ax.axvline(x=0, color='gray', linestyle='--', linewidth=0.8, zorder=0)

# Add legend and layout adjustments
ax.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale TP Loading in Surface Runoff": [0.4, 1.9, 0.05, 0.56, 0.01, 0.13, 0.08, 0.25, 0.51, 1.38, 0.45, 0.89, 0.37, 0.92, 0.02, 0.34, 0.6, 4.55, 3.32, 8.91],
    "Field-scale TP Loading in Tile Flow": [0.3, 2.3, 0.14, 1.62, 0.21, 2.14, 0.17, 0.26, 0.6, 0.93, 0.64, 1.47, 0.66, 1.34, 0.58, 1.47, 0.15, 0.72, 0.01, 0.46, 0.73, 8.36, 2.02, 3.21, 1.04, 3.45, 0.58, 0.6, 0.18, 0.9, 0.24, 1.53, 0.49, 6.93, 0.27, 2.63, 0.01, 0.08, 0.01, 0.19, 0.44, 0.75, 2.85],
    "Field-scale DRP Loading in Surface Runoff": [0.17, 0.43, 0.003, 0.08, 0.001, 0.013, 0.01, 0.08, 0.26, 0.34, 0.11, 0.21, 0.18, 0.24, 0.15, 0.38, 0.009, 0.12, 0.22, 0.95, 0.52, 7.84, 3.32, 7.84, 0.39, 0.35],
    "Field-scale DRP Loading in Tile Flow": [0.21, 0.53, 0.008, 0.152, 0.01, 0.12, 0.017, 0.023, 0.06, 0.28, 0.14, 0.32, 0.19, 0.55, 0.24, 0.51, 0.02, 0.2, 0.01, 0.03, 0.003, 0.104, 0.19, 6.28, 0.18, 0.9, 0.27, 2.43, 0.28, 0.34, 0.06, 0.69, 0.22, 0.95, 0.36, 5.86, 0.13, 2.08, 0.01, 0.06, 0.01, 0.15, 0.36, 0.61, 0.89, 0.79, 0.68, 0.344, 0.383],
    "Field-scale PP Loading in Surface Runoff": [0.08, 0.73, 0.04, 0.51, 0.008, 0.102, 0.07, 0.2, 0.46, 0.99, 0.14, 0.29, 0.23, 0.58, 0.17, 0.47, 1.29, 1.14],
    "Field-scale PP Loading in Tile Flow": [0.09, 1.77, 0.1, 1.33, 0.19, 1.82, 0.15, 0.23, 0.33, 0.64, 0.23, 1.15, 0.24, 1.27, 0.17, 0.98, 0.46, 1.46, 2.11, 3.14],
    "Watershed-scale TP Loading in Surface Runoff": [0.94, 0.52, 1.85, 0.18, 1.8, 0.77, 1.11, 0.99, 1.85, 1.1, 3.3],
    "Watershed-scale TP Loading in Tile Flow": [0.28, 0.92, 0.003, 0.322, 0.18],
    "Watershed-scale DRP Loading in Surface Runoff": [0.1, 0.15, 0.33, 1.26, 0.471, 0.05, 0.13, 0.34, 0.051, 0.34, 0.82, 0.63],
    "Watershed-scale DRP Loading in Tile Flow": [0.22, 0.84, 0.11, 0.23, 0.002, 0.248, 0.1, 0.017, 0.023],
}

# Perform Monte Carlo Simulation for each dataset
results = {}
for key, values in data.items():
    # Fit a log-normal distribution (appropriate for environmental data)
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    
    # Generate 10,000 random samples
    simulated_samples = stats.lognorm.rvs(shape, loc, scale, size=10000)
    
    # Calculate statistics
    ci_lower = np.percentile(simulated_samples, 2.5)
    ci_upper = np.percentile(simulated_samples, 97.5)
    
    # Calculate geometric mean and geometric standard deviation
    log_mean = np.mean(np.log(simulated_samples))
    log_std_dev = np.std(np.log(simulated_samples))
    geo_mean = np.exp(log_mean)
    geo_std_dev = np.exp(log_std_dev)
    
    # Store results
    results[key] = {
        "geometric_mean": geo_mean,
        "geometric_std_dev": geo_std_dev,
        "ci_lower": ci_lower,
        "ci_upper": ci_upper,
    }

# Print results
for key, result in results.items():
    print(f"{key}:")
    print(f"  Geometric Mean: {result['geometric_mean']:.2f}")
    print(f"  Geometric Std Dev: {result['geometric_std_dev']:.2f}")
    print(f"  95% CI: [{result['ci_lower']:.2f}, {result['ci_upper']:.2f}]")
# Out:
# Field-scale TP Loading in Surface Runoff:
#   Geometric Mean: 0.42
#   Geometric Std Dev: 5.33
#   95% CI: [0.02, 11.27]
# Field-scale TP Loading in Tile Flow:
#   Geometric Mean: 0.55
#   Geometric Std Dev: 4.59
#   95% CI: [0.03, 10.95]
# Field-scale DRP Loading in Surface Runoff:
#   Geometric Mean: 0.16
#   Geometric Std Dev: 7.92
#   95% CI: [0.00, 8.87]
# Field-scale DRP Loading in Tile Flow:
#   Geometric Mean: 0.18
#   Geometric Std Dev: 5.47
#   95% CI: [0.01, 5.03]
# Field-scale PP Loading in Surface Runoff:
#   Geometric Mean: 0.24
#   Geometric Std Dev: 3.62
#   95% CI: [0.02, 2.94]
# Field-scale PP Loading in Tile Flow:
#   Geometric Mean: 0.54
#   Geometric Std Dev: 3.02
#   95% CI: [0.06, 4.77]
# Watershed-scale TP Loading in Surface Runoff:
#   Geometric Mean: 1.05
#   Geometric Std Dev: 2.12
#   95% CI: [0.24, 4.47]
# Watershed-scale TP Loading in Tile Flow:
#   Geometric Mean: 0.13
#   Geometric Std Dev: 7.24
#   95% CI: [0.00, 6.27]
# Watershed-scale DRP Loading in Surface Runoff:
#   Geometric Mean: 0.25
#   Geometric Std Dev: 2.75
#   95% CI: [0.03, 1.77]
# Watershed-scale DRP Loading in Tile Flow:
#   Geometric Mean: 0.08
#   Geometric Std Dev: 5.65
#   95% CI: [0.00, 2.44]

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale TP Loading in Surface Runoff": [0.4, 1.9, 0.05, 0.56, 0.01, 0.13, 0.08, 0.25, 0.51, 1.38, 0.45, 0.89, 0.37, 0.92, 0.02, 0.34, 0.6, 4.55, 3.32, 8.91],
    "Field-scale TP Loading in Tile Flow": [0.3, 2.3, 0.14, 1.62, 0.21, 2.14, 0.17, 0.26, 0.6, 0.93, 0.64, 1.47, 0.66, 1.34, 0.58, 1.47, 0.15, 0.72, 0.01, 0.46, 0.73, 8.36, 2.02, 3.21, 1.04, 3.45, 0.58, 0.6, 0.18, 0.9, 0.24, 1.53, 0.49, 6.93, 0.27, 2.63, 0.01, 0.08, 0.01, 0.19, 0.44, 0.75, 2.85],
    "Field-scale DRP Loading in Surface Runoff": [0.17, 0.43, 0.003, 0.08, 0.001, 0.013, 0.01, 0.08, 0.26, 0.34, 0.11, 0.21, 0.18, 0.24, 0.15, 0.38, 0.009, 0.12, 0.22, 0.95, 0.52, 7.84, 3.32, 7.84, 0.39, 0.35],
    "Field-scale DRP Loading in Tile Flow": [0.21, 0.53, 0.008, 0.152, 0.01, 0.12, 0.017, 0.023, 0.06, 0.28, 0.14, 0.32, 0.19, 0.55, 0.24, 0.51, 0.02, 0.2, 0.01, 0.03, 0.003, 0.104, 0.19, 6.28, 0.18, 0.9, 0.27, 2.43, 0.28, 0.34, 0.06, 0.69, 0.22, 0.95, 0.36, 5.86, 0.13, 2.08, 0.01, 0.06, 0.01, 0.15, 0.36, 0.61, 0.89, 0.79, 0.68, 0.344, 0.383],
    "Field-scale PP Loading in Surface Runoff": [0.08, 0.73, 0.04, 0.51, 0.008, 0.102, 0.07, 0.2, 0.46, 0.99, 0.14, 0.29, 0.23, 0.58, 0.17, 0.47, 1.29, 1.14],
    "Field-scale PP Loading in Tile Flow": [0.09, 1.77, 0.1, 1.33, 0.19, 1.82, 0.15, 0.23, 0.33, 0.64, 0.23, 1.15, 0.24, 1.27, 0.17, 0.98, 0.46, 1.46, 2.11, 3.14],
    "Watershed-scale TP Loading in Surface Runoff": [0.94, 0.52, 1.85, 0.18, 1.8, 0.77, 1.11, 0.99, 1.85, 1.1, 3.3],
    "Watershed-scale TP Loading in Tile Flow": [0.28, 0.92, 0.003, 0.322, 0.18],
    "Watershed-scale DRP Loading in Surface Runoff": [0.1, 0.15, 0.33, 1.26, 0.471, 0.05, 0.13, 0.34, 0.051, 0.34, 0.82, 0.63],
    "Watershed-scale DRP Loading in Tile Flow": [0.22, 0.84, 0.11, 0.23, 0.002, 0.248, 0.1, 0.017, 0.023],
}

# Perform Monte Carlo Simulation for each dataset
results = {}
for key, values in data.items():
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    simulated_samples = stats.lognorm.rvs(shape, loc, scale, size=10000)
    ci_lower = np.percentile(simulated_samples, 2.5)
    ci_upper = np.percentile(simulated_samples, 97.5)
    log_mean = np.mean(np.log(simulated_samples))
    log_std_dev = np.std(np.log(simulated_samples))
    geo_mean = np.exp(log_mean)
    geo_std_dev = np.exp(log_std_dev)
    results[key] = {
        "geometric_mean": geo_mean,
        "geometric_std_dev": geo_std_dev,
        "ci_lower": ci_lower,
        "ci_upper": ci_upper,
    }

# Extract results for plotting
categories = list(results.keys())
geo_means = [results[key]["geometric_mean"] for key in categories]
geo_std_devs = [results[key]["geometric_std_dev"] for key in categories]
ci_lowers = [results[key]["ci_lower"] for key in categories]
ci_uppers = [results[key]["ci_upper"] for key in categories]

# Plot the results
fig, ax = plt.subplots(figsize=(12, 8))

# Add error bars for geometric mean ± 95% CI
for i, (mean, ci_lower, ci_upper) in enumerate(zip(geo_means, ci_lowers, ci_uppers)):
    ax.errorbar(x=mean, y=i, xerr=[[mean - ci_lower], [ci_upper - mean]], fmt='o', color='blue', label='Geometric Mean ± 95% CI' if i == 0 else "", capsize=5)

# Add error bars for geometric mean ± geometric std dev
for i, (mean, std_dev) in enumerate(zip(geo_means, geo_std_devs)):
    ax.errorbar(x=mean, y=i, xerr=[[mean / std_dev], [mean * std_dev]], fmt='o', color='green', label='Geometric Std Dev' if i == 0 else "", capsize=5)

# Add labels and formatting
ax.set_yticks(range(len(categories)))
ax.set_yticklabels(categories, fontsize=10)
ax.set_xlabel("Loading Values (kg/ha)", fontsize=12)
ax.set_title("Monte Carlo Simulation Results: Geometric Mean, Std Dev, and 95% CIs", fontsize=14, fontweight='bold')
ax.axvline(x=0, color='gray', linestyle='--', linewidth=0.8, zorder=0)

# Add legend and layout adjustments
ax.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale TP Loading in Surface Runoff": [0.4, 1.9, 0.05, 0.56, 0.01, 0.13, 0.08, 0.25, 0.51, 1.38, 0.45, 0.89, 0.37, 0.92, 0.02, 0.34, 0.6, 4.55, 3.32, 8.91],
    "Field-scale TP Loading in Tile Flow": [0.3, 2.3, 0.14, 1.62, 0.21, 2.14, 0.17, 0.26, 0.6, 0.93, 0.64, 1.47, 0.66, 1.34, 0.58, 1.47, 0.15, 0.72, 0.01, 0.46, 0.73, 8.36, 2.02, 3.21, 1.04, 3.45, 0.58, 0.6, 0.18, 0.9, 0.24, 1.53, 0.49, 6.93, 0.27, 2.63, 0.01, 0.08, 0.01, 0.19, 0.44, 0.75, 2.85],
    "Field-scale DRP Loading in Surface Runoff": [0.17, 0.43, 0.003, 0.08, 0.001, 0.013, 0.01, 0.08, 0.26, 0.34, 0.11, 0.21, 0.18, 0.24, 0.15, 0.38, 0.009, 0.12, 0.22, 0.95, 0.52, 7.84, 3.32, 7.84, 0.39, 0.35],
    "Field-scale DRP Loading in Tile Flow": [0.21, 0.53, 0.008, 0.152, 0.01, 0.12, 0.017, 0.023, 0.06, 0.28, 0.14, 0.32, 0.19, 0.55, 0.24, 0.51, 0.02, 0.2, 0.01, 0.03, 0.003, 0.104, 0.19, 6.28, 0.18, 0.9, 0.27, 2.43, 0.28, 0.34, 0.06, 0.69, 0.22, 0.95, 0.36, 5.86, 0.13, 2.08, 0.01, 0.06, 0.01, 0.15, 0.36, 0.61, 0.89, 0.79, 0.68, 0.344, 0.383],
    "Field-scale PP Loading in Surface Runoff": [0.08, 0.73, 0.04, 0.51, 0.008, 0.102, 0.07, 0.2, 0.46, 0.99, 0.14, 0.29, 0.23, 0.58, 0.17, 0.47, 1.29, 1.14],
    "Field-scale PP Loading in Tile Flow": [0.09, 1.77, 0.1, 1.33, 0.19, 1.82, 0.15, 0.23, 0.33, 0.64, 0.23, 1.15, 0.24, 1.27, 0.17, 0.98, 0.46, 1.46, 2.11, 3.14],
    "Watershed-scale TP Loading in Surface Runoff": [0.94, 0.52, 1.85, 0.18, 1.8, 0.77, 1.11, 0.99, 1.85, 1.1, 3.3],
    "Watershed-scale TP Loading in Tile Flow": [0.28, 0.92, 0.003, 0.322, 0.18],
    "Watershed-scale DRP Loading in Surface Runoff": [0.1, 0.15, 0.33, 1.26, 0.471, 0.05, 0.13, 0.34, 0.051, 0.34, 0.82, 0.63],
    "Watershed-scale DRP Loading in Tile Flow": [0.22, 0.84, 0.11, 0.23, 0.002, 0.248, 0.1, 0.017, 0.023],
}

# Perform Monte Carlo Simulation for each dataset
results = {}
for key, values in data.items():
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    simulated_samples = stats.lognorm.rvs(shape, loc, scale, size=10000)
    ci_lower = np.percentile(simulated_samples, 2.5)
    ci_upper = np.percentile(simulated_samples, 97.5)
    mean = np.mean(simulated_samples)
    std_dev = np.std(simulated_samples)
    results[key] = {
        "mean": mean,
        "std_dev": std_dev,
        "ci_lower": ci_lower,
        "ci_upper": ci_upper,
    }

# Extract results for plotting
categories = list(results.keys())
all_means = [results[key]["mean"] for key in categories]
all_ci_lowers = [results[key]["ci_lower"] for key in categories]
all_ci_uppers = [results[key]["ci_upper"] for key in categories]

# Plot the results
fig, ax = plt.subplots(figsize=(12, 8))

# Add error bars for mean ± 95% CI
for i, (mean, ci_lower, ci_upper) in enumerate(zip(all_means, all_ci_lowers, all_ci_uppers)):
    ax.errorbar(x=mean, y=i, xerr=[[mean - ci_lower], [ci_upper - mean]], fmt='o', color='blue', label='Mean ± 95% CI' if i == 0 else "", capsize=5)

# Add labels and formatting
ax.set_yticks(range(len(categories)))
ax.set_yticklabels(categories, fontsize=10)
ax.set_xlabel("Loading Values (kg/ha)", fontsize=12)
ax.set_title("Monte Carlo Simulation Results: Means and 95% CIs", fontsize=14, fontweight='bold')
ax.axvline(x=0, color='gray', linestyle='--', linewidth=0.8, zorder=0)

# Add legend and layout adjustments
ax.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale NO3-N Loading in Tile Flow": [3.1, 3.8, 1, 18.4, 3.6, 15.4, 24.63, 43.76, 0.67, 5.88, 2.88, 8.34, 5.71, 42.95, 23.9, 56.8, 2.9, 153, 17, 37],
    "Field-scale TN Loading in Tile Flow": [34.73, 52.86, 2.09, 20.63, 28.3, 64.2, 6.6, 97.7],
    "Watershed-scale NO3-N Loading in Surface Runoff": [9.15, 11.55, 15.54, 5.27, 4.67, 2.4, 2.6, 1.5],
    "Watershed-scale NO3-N Loading in Tile Flow": [22.8, 27.36, 6.5],
    "Watershed-scale TN Loading in Surface Runoff": [0.93, 6.4, 6, 9.9, 16.35, 15.11],
}

# Perform Monte Carlo Simulation for each dataset
results = {}
for key, values in data.items():
    # Fit a log-normal distribution (appropriate for environmental data)
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    
    # Generate 10,000 random samples
    simulated_samples = stats.lognorm.rvs(shape, loc, scale, size=10000)
    
    # Calculate statistics
    ci_lower = np.percentile(simulated_samples, 2.5)
    ci_upper = np.percentile(simulated_samples, 97.5)
    mean = np.mean(simulated_samples)
    median = np.median(simulated_samples)
    std_dev = np.std(simulated_samples)
    
    # Store results
    results[key] = {
        "mean": mean,
        "median": median,
        "std_dev": std_dev,
        "ci_lower": ci_lower,
        "ci_upper": ci_upper,
    }

# Print results
for key, result in results.items():
    print(f"{key}:")
    print(f"  Mean: {result['mean']:.2f}")
    print(f"  Median: {result['median']:.2f}")
    print(f"  Std Dev: {result['std_dev']:.2f}")
    print(f"  95% CI: [{result['ci_lower']:.2f}, {result['ci_upper']:.2f}]")
# Out:
# Field-scale NO3-N Loading in Tile Flow:
#   Mean: 26.57
#   Median: 9.87
#   Std Dev: 64.30
#   95% CI: [0.65, 160.75]
# Field-scale TN Loading in Tile Flow:
#   Mean: 49.17
#   Median: 23.26
#   Std Dev: 83.82
#   95% CI: [2.15, 258.79]
# Watershed-scale NO3-N Loading in Surface Runoff:
#   Mean: 6.74
#   Median: 4.99
#   Std Dev: 6.23
#   95% CI: [1.12, 23.30]
# Watershed-scale NO3-N Loading in Tile Flow:
#   Mean: 19.50
#   Median: 15.89
#   Std Dev: 13.99
#   95% CI: [4.57, 55.54]
# Watershed-scale TN Loading in Surface Runoff:
#   Mean: 10.48
#   Median: 6.64
#   Std Dev: 12.34
#   95% CI: [1.01, 42.09]

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale NO3-N Loading in Tile Flow": [3.1, 3.8, 1, 18.4, 3.6, 15.4, 24.63, 43.76, 0.67, 5.88, 2.88, 8.34, 5.71, 42.95, 23.9, 56.8, 2.9, 153, 17, 37],
    "Field-scale TN Loading in Tile Flow": [34.73, 52.86, 2.09, 20.63, 28.3, 64.2, 6.6, 97.7],
    "Watershed-scale NO3-N Loading in Surface Runoff": [9.15, 11.55, 15.54, 5.27, 4.67, 2.4, 2.6, 1.5],
    "Watershed-scale NO3-N Loading in Tile Flow": [22.8, 27.36, 6.5],
    "Watershed-scale TN Loading in Surface Runoff": [0.93, 6.4, 6, 9.9, 16.35, 15.11],
}

# Perform Monte Carlo Simulation and store statistics
results = {}
all_means, all_medians, all_ci_lowers, all_ci_uppers, categories = [], [], [], [], []
for key, values in data.items():
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    simulated_samples = stats.lognorm.rvs(shape, loc, scale, size=10000)
    
    mean = np.mean(simulated_samples)
    median = np.median(simulated_samples)
    ci_lower = np.percentile(simulated_samples, 2.5)
    ci_upper = np.percentile(simulated_samples, 97.5)
    
    all_means.append(mean)
    all_medians.append(median)
    all_ci_lowers.append(ci_lower)
    all_ci_uppers.append(ci_upper)
    categories.append(key)

# Plot the results
fig, ax = plt.subplots(figsize=(12, 8))

for i, (mean, ci_lower, ci_upper) in enumerate(zip(all_means, all_ci_lowers, all_ci_uppers)):
    ax.errorbar(x=mean, y=i, xerr=[[mean - ci_lower], [ci_upper - mean]], fmt='o', color='blue', label='Mean ± 95% CI' if i == 0 else "", capsize=5)

ax.scatter(all_medians, range(len(categories)), color='red', label='Median', zorder=3)

ax.set_yticks(range(len(categories)))
ax.set_yticklabels(categories, fontsize=10)
ax.set_xlabel("Loading Values (kg/ha)", fontsize=12)
ax.set_title("Monte Carlo Simulation Results: Means and 95% CIs", fontsize=14, fontweight='bold')
ax.axvline(x=0, color='gray', linestyle='--', linewidth=0.8, zorder=0)

ax.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale NO3-N Loading in Tile Flow": [3.1, 3.8, 1, 18.4, 3.6, 15.4, 24.63, 43.76, 0.67, 5.88, 2.88, 8.34, 5.71, 42.95, 23.9, 56.8, 2.9, 153, 17, 37],
    "Field-scale TN Loading in Tile Flow": [34.73, 52.86, 2.09, 20.63, 28.3, 64.2, 6.6, 97.7],
    "Watershed-scale NO3-N Loading in Surface Runoff": [9.15, 11.55, 15.54, 5.27, 4.67, 2.4, 2.6, 1.5],
    "Watershed-scale NO3-N Loading in Tile Flow": [22.8, 27.36, 6.5],
    "Watershed-scale TN Loading in Surface Runoff": [0.93, 6.4, 6, 9.9, 16.35, 15.11],
}

# Perform Monte Carlo Simulation for each dataset
results = {}
for key, values in data.items():
    # Fit a log-normal distribution (appropriate for environmental data)
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    
    # Generate 10,000 random samples
    simulated_samples = stats.lognorm.rvs(shape, loc, scale, size=10000)
    
    # Calculate statistics
    ci_lower = np.percentile(simulated_samples, 2.5)
    ci_upper = np.percentile(simulated_samples, 97.5)
    
    # Calculate geometric mean and geometric standard deviation
    log_mean = np.mean(np.log(simulated_samples))
    log_std_dev = np.std(np.log(simulated_samples))
    geo_mean = np.exp(log_mean)
    geo_std_dev = np.exp(log_std_dev)
    
    # Store results
    results[key] = {
        "geometric_mean": geo_mean,
        "geometric_std_dev": geo_std_dev,
        "ci_lower": ci_lower,
        "ci_upper": ci_upper,
    }

# Print results
for key, result in results.items():
    print(f"{key}:")
    print(f"  Geometric Mean: {result['geometric_mean']:.2f}")
    print(f"  Geometric Std Dev: {result['geometric_std_dev']:.2f}")
    print(f"  95% CI: [{result['ci_lower']:.2f}, {result['ci_upper']:.2f}]")
# Out:
# Field-scale NO3-N Loading in Tile Flow:
#   Geometric Mean: 10.06
#   Geometric Std Dev: 4.03
#   95% CI: [0.65, 153.88]
# Field-scale TN Loading in Tile Flow:
#   Geometric Mean: 23.92
#   Geometric Std Dev: 3.27
#   95% CI: [2.32, 234.24]
# Watershed-scale NO3-N Loading in Surface Runoff:
#   Geometric Mean: 5.00
#   Geometric Std Dev: 2.15
#   95% CI: [1.11, 22.09]
# Watershed-scale NO3-N Loading in Tile Flow:
#   Geometric Mean: 15.87
#   Geometric Std Dev: 1.89
#   95% CI: [4.55, 55.40]
# Watershed-scale TN Loading in Surface Runoff:
#   Geometric Mean: 6.72
#   Geometric Std Dev: 2.61
#   95% CI: [1.03, 44.08]

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Dataset for Monte Carlo Simulation
data = {
    "Field-scale NO3-N Loading in Tile Flow": [3.1, 3.8, 1, 18.4, 3.6, 15.4, 24.63, 43.76, 0.67, 5.88, 2.88, 8.34, 5.71, 42.95, 23.9, 56.8, 2.9, 153, 17, 37],
    "Field-scale TN Loading in Tile Flow": [34.73, 52.86, 2.09, 20.63, 28.3, 64.2, 6.6, 97.7],
    "Watershed-scale NO3-N Loading in Surface Runoff": [9.15, 11.55, 15.54, 5.27, 4.67, 2.4, 2.6, 1.5],
    "Watershed-scale NO3-N Loading in Tile Flow": [22.8, 27.36, 6.5],
    "Watershed-scale TN Loading in Surface Runoff": [0.93, 6.4, 6, 9.9, 16.35, 15.11],
}

# Perform Monte Carlo Simulation and store statistics
results = {}
geo_means, geo_std_devs, ci_lowers, ci_uppers, categories = [], [], [], [], []
for key, values in data.items():
    # Fit a log-normal distribution
    shape, loc, scale = stats.lognorm.fit(values, floc=0)
    simulated_samples = stats.lognorm.rvs(shape, loc, scale, size=10000)
    
    # Calculate geometric mean and geometric standard deviation
    log_mean = np.mean(np.log(simulated_samples))
    log_std_dev = np.std(np.log(simulated_samples))
    geo_mean = np.exp(log_mean)
    geo_std_dev = np.exp(log_std_dev)
    
    # Calculate 95% confidence intervals
    ci_lower = np.percentile(simulated_samples, 2.5)
    ci_upper = np.percentile(simulated_samples, 97.5)
    
    # Append results for plotting
    geo_means.append(geo_mean)
    geo_std_devs.append(geo_std_dev)
    ci_lowers.append(ci_lower)
    ci_uppers.append(ci_upper)
    categories.append(key)

# Plot the results
fig, ax = plt.subplots(figsize=(12, 8))

# Plot error bars for geometric mean ± 95% CI
for i, (mean, ci_lower, ci_upper) in enumerate(zip(geo_means, ci_lowers, ci_uppers)):
    ax.errorbar(x=mean, y=i, xerr=[[mean - ci_lower], [ci_upper - mean]], fmt='o', color='blue', label='Geometric Mean ± 95% CI' if i == 0 else "", capsize=5)

# Plot error bars for geometric mean ± geometric standard deviation
for i, (mean, std_dev) in enumerate(zip(geo_means, geo_std_devs)):
    ax.errorbar(x=mean, y=i, xerr=[[mean / std_dev], [mean * std_dev]], fmt='o', color='green', label='Geometric Std Dev' if i == 0 else "", capsize=5)

# Format plot
ax.set_yticks(range(len(categories)))
ax.set_yticklabels(categories, fontsize=10)
ax.set_xlabel("Loading Values (kg/ha)", fontsize=12)
ax.set_title("Monte Carlo Simulation Results: Geometric Mean, Std Dev, and 95% CIs", fontsize=14, fontweight='bold')
ax.axvline(x=0, color='gray', linestyle='--', linewidth=0.8, zorder=0)

# Add legend and adjust layout
ax.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.show()
